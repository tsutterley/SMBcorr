# %%
import pointCollection as pc
import numpy as np
import scipy.stats as ss
import matplotlib.pyplot as plt
import h5py
# %matplotlib notebook
import scipy.interpolate as si
import scipy.stats as ss
import h5py
import os
import re
import matplotlib.gridspec as gridspec
import pandas as pd
import seaborn as sns

# change this data root to match your own
data_root = '/Volumes/ice2/ben/MAR/ATL11_with_corrections/'

# %%
drainage_basins=pc.grid.data().from_geotif(data_root+'/drainage_basins.tif')
gimp_mask=pc.grid.data().from_geotif(data_root+'/GimpIceMask_1km.tif')
v_mask=pc.grid.data().from_geotif(data_root+'/vel_mask_annual_sigma_lt_20.tif')
v_mask.index(np.arange(0, v_mask.shape[0], 5), np.arange(0, v_mask.shape[1], 5));
dbi=si.RegularGridInterpolator((drainage_basins.y, drainage_basins.x), drainage_basins.z, method='nearest')
# Out:
# bounds=None
# bounds=None
# bounds=None

# %%
def RDE(x, f=0.68, scale=0.5):
    xs=x.copy()
    xs=np.isfinite(xs)   # this changes xs from values to a boolean
    N=len(xs.nonzero()[0])
    if N<2 :
        return np.nan
    ind=np.arange(0.5, N)
    
    
    LH=np.interp(np.array([0.5-f/2, 0.5+f/2])*N, ind, np.sort(x[xs]))
    #print('LH =',LH)
    return (LH[1]-LH[0])*scale  # trying to get some kind of a width of the data ~variance

# %% [markdown]
# ## read in the data file.
# The data were written by the 'reduce_firn_dh' notebook.  It contains one top-level group for each model, and beneath that, one group for each epoch.  Within each epoch, the data represent a 2.5-km blockmedian of the corrected elevation-change values.  This gives a smaller number of difference values for each region, and makes a file of reasonable size.
#
# Applying the blockmedian to the drainage basin variable didn't work well (cells containing borders aren't represented well), so let's repeat the interpolation for the cell locations.

# %%
! ls -lt {data_root}
# Out:
# total 34723627
# -rw-r--r-- 1 ben ben   126178474 Oct  1 12:52 combined_xover_at_differences_wrtc3_v2_zsurf.h5
# -rw-r--r-- 1 ben ben   111349789 Oct  1 12:52 combined_xover_at_differences_v2_zsurf.h5
# -rw-r--r-- 1 ben ben   126207790 Oct  1 12:33 combined_xover_at_differences_wrtc3_v2_SMB.h5
# -rw-r--r-- 1 ben ben   111425217 Oct  1 12:24 combined_xover_at_differences_v2_SMB.h5
# drwxr-xr-x 2 ben ben           8 Sep 28 20:52 temp
# -rw-r--r-- 1 ben ben  8264279978 Sep 27 22:05 007_crossover_data_v1.h5
# drwxr-xr-x 2 ben ben           4 Sep 27 22:02 old
# -rw-r--r-- 1 ben ben   126191253 Sep 22 09:16 combined_xover_at_differences_wrtc3.h5
# -rw-r--r-- 1 ben ben   111403226 Sep 21 08:39 combined_xover_at_differences_v1.h5
# -rw-r--r-- 1 ben ben   112593942 Sep 14 11:42 combined_xover_at_differences_wrtc3_v1.h5
# -rw-r--r-- 1 ben ben         395 Sep  2 15:12 update_corrections
# -rw-r--r-- 1 ben ben         269 Sep  2 15:09 update_corrections~
# -rw-r--r-- 1 ben ben 11579714767 Aug 25 10:51 relU07_dump_every_4th.h5
# -rw-r--r-- 1 ben ben 15225563598 Aug 25 10:49 U07_crossover_data.h5
# -rw-r--r-- 1 ben ben   123261676 Aug 25 09:24 combined_xover_at_differences.h5
# -rw-r--r-- 1 ben ben      692434 Jul 30 10:48 vel_mask_annual_nmad_lt_20_simplified.tif
# -rw-r--r-- 1 ben ben     8824679 Jun  9 12:10 vel_mask_annual_sigma_lt_20.tif
# -rw-r--r-- 1 ben ben       99192 Jun  9 12:09 drainage_basins.tif
# -rw-r--r-- 1 ben ben     4044014 Jun  9 12:09 GimpIceMask_1km.tif

# %%
data_file=os.path.join(data_root+'/combined_xover_at_differences_v2_zsurf.h5')


strings_xover = ['2018.Q4-2019.Q2','2019.Q1-2019.Q2']
strings_at=['2019.Q2-2019.Q3', '2019.Q3-2019.Q4', '2019.Q4-2020.Q1']
epochs=strings_xover+strings_at

D={}
with h5py.File(data_file,'r') as h5f:
    models=list(h5f.keys())
    print(models)
for model in models:
    D[model]={}
    for epoch in epochs:
        this_group='/'.join(['',model, epoch])
        D[model][epoch]=pc.data().from_h5(data_file, group=this_group)
        D[model][epoch].assign({'basin':np.floor(dbi.__call__((D[model][epoch].y, D[model][epoch].x))*10)/10})
# Out:
# ['GSFC_fdm_v1_1_zsurf', 'MARv3_11_2_ERA_20km_zsurf', 'MARv3_11_2_ERA_6km_zsurf', 'MARv3_11_2_NCEP_20km_zsurf']

# %% [markdown]
# ### Calculate the percentiles for all models and for all epochs
# We'll save the percentiles of the elevation differences for all the models to look at collectively

# %%
h_ranges=[(-10, 2000), (2000, 5000), (-10, 5000)]
h_range_cols={h_ranges[0]:0, h_ranges[1]:1}
h_range_colors={h_ranges[0]:'r', h_ranges[1]:'g'}
h_range_names=['< 2000', '> 2000']

basins=np.arange(1,9)

percentiles=np.array([5, 16, 50, 84, 95])
pct={epoch :\
     {model:\
      {h_range:\
       {rc:np.zeros((basins.size, percentiles.size)) for rc in ['raw', 'corr']}\
       for h_range in h_ranges}\
      for model in models}
     for epoch in epochs + ['melt', 'non_melt', 'all']}

for count, model in enumerate(models):
    for epoch in epochs +['melt', 'non_melt','all']:
        for h_range in h_ranges:
            pct[epoch][model][h_range]['count']=np.zeros(basins.size)

for count, model in enumerate(models): 
    for epoch in epochs:
        for basin in basins:
            for h_range in h_ranges: 
                Dsub=D[model][epoch]
                els = np.floor(Dsub.basin)==basin
                els &= (Dsub.h0 > h_range[0])
                els &= (Dsub.h0 < h_range[1])
                els &= np.isfinite(Dsub.dh_corr)
                Dsub=Dsub[els]
                pct[epoch][model][h_range]['raw'][basin-1,:]=ss.scoreatpercentile(Dsub.dh, percentiles)
                pct[epoch][model][h_range]['corr'][basin-1,:]=ss.scoreatpercentile(Dsub.dh_corr, percentiles)
                pct[epoch][model][h_range]['count'][basin-1]=Dsub.size

# %%
# melt season runs May 15 -> August 1  (May begins 4*30 days into the new year, 2019 starts ~day 365.25)
melt_season=np.array([365.25+4*30+15, 365.25+7*30])*3600*24

for count, model in enumerate(models): 
    for basin in basins:
        for h_range in h_ranges: 
            melt_data=[]
            non_melt_data=[]
            all_data=[]
            for epoch in epochs:
                Dsub=D[model][epoch]
                els = np.floor(Dsub.basin)==basin
                els &= (Dsub.h0 > h_range[0])
                els &= (Dsub.h0 < h_range[1])
                els &= np.isfinite(Dsub.dh_corr)
                Dsub=Dsub[els]
                melt_days = ( ((Dsub.t0 < melt_season[0] ) & (Dsub.t1 > melt_season[0]) ) *(Dsub.t1-melt_season[0]) + \
                ((Dsub.t0 > melt_season[0] ) & (Dsub.t1 < melt_season[1]) )*(Dsub.t1-Dsub.t0) + \
                ((Dsub.t1 > melt_season[0] ) & (Dsub.t1 < melt_season[1]) ) *(melt_season[1]-Dsub.t1) )/24/3600.
                melt_data += [Dsub[melt_days>40]]
                non_melt_data += [Dsub[melt_days < 7 ]]
                all_data += [Dsub]
            temp=pc.data().from_list(melt_data)
            pct['melt'][model][h_range]['raw'][basin-1,:] = ss.scoreatpercentile(temp.dh, percentiles)
            pct['melt'][model][h_range]['corr'][basin-1,:] = ss.scoreatpercentile(temp.dh_corr, percentiles)
            pct['melt'][model][h_range]['count'][basin-1]=temp.size
            temp=pc.data().from_list(non_melt_data)
            pct['non_melt'][model][h_range]['raw'][basin-1,:] = ss.scoreatpercentile(temp.dh, percentiles)
            pct['non_melt'][model][h_range]['corr'][basin-1,:] = ss.scoreatpercentile(temp.dh_corr, percentiles)
            pct['non_melt'][model][h_range]['count'][basin-1]=temp.size
            temp=pc.data().from_list(all_data)
            pct['all'][model][h_range]['raw'][basin-1,:] = ss.scoreatpercentile(temp.dh, percentiles)
            pct['all'][model][h_range]['corr'][basin-1,:] = ss.scoreatpercentile(temp.dh_corr, percentiles)
            pct['all'][model][h_range]['count'][basin-1]=temp.size

# %%
{basin:pct['melt'][model][h_ranges[0]]['count'][basin-1]/pct['non_melt'][model][h_ranges[0]]['count'][basin-1] for basin in basins}
# Out:
# {1: 0.22896728285832613,
#  2: 0.22909161282639115,
#  3: 0.19431507949253252,
#  4: 0.06674405107370865,
#  5: 0.08287629494210846,
#  6: 0.17581642616903548,
#  7: 0.1958509142053446,
#  8: 0.20091979754720654}

# %% [markdown]
# ### Tables of statistics:
# This function reports a summary of a particular statistic for the different models.

# %%
models
# Out:
# ['GSFC_fdm_v1_1_zsurf',
#  'MARv3_11_2_ERA_20km_zsurf',
#  'MARv3_11_2_ERA_6km_zsurf',
#  'MARv3_11_2_NCEP_20km_zsurf']

# %%
sn={'raw':'raw',
        'GSFC_fdm_v1_1_zsurf':'GSFC_v1.1',
#        'MARv3_11_ERA_zsurf':'M3.11ERA.15', 
        'MARv3_11_2_ERA_6km_zsurf':'M3.11.2ERA6',
#        'MARv3_11_2_ERA_20km_zsurf':'M3.11.2ERA20',
       'MARv3_11_2_NCEP_20km_zsurf':'M311.2NC20'
        ''}


sigma_sn={model:f'$\sigma_{{{sn[model]}}}$' for model in sn.keys()}

# %%
def all_basin_stats(pct, epoch, h_range, var):
    if var=='lt_tail':
        p1=1
        p0=0
    elif var == 'ctr':
        p1=3
        p0=1
    elif var == 'rt_tail':
        p1=4
        p0=3

    #models=['GSFC_fdm_v1_zsurf', 'MARv3_11_ERA_zsurf', 'MARv3_11_2_ERA_10km_zsurf',
    # 'MARv3_11_2_ERA_20km_zsurf',
    # 'MARv3_11_2_NCEP_20km_zsurf']
    models=['GSFC_fdm_v1_1_zsurf',  'MARv3_11_2_ERA_6km_zsurf',
       'MARv3_11_2_NCEP_20km_zsurf']
    
    
    #short names

    sigma_sn={model:f'$\sigma_{{{sn[model]}}}$' for model in sn.keys()}
        
    column_list=['basin','raw', sigma_sn['raw']]
    for model in models:
        column_list += [sn[model]]
        column_list += [sigma_sn[model]]

    df={var:np.zeros(len(basins)) for var in column_list}
    df['basin']=np.arange(len(basins), dtype=int)+1
    
    # first two lines give  model, and resolution
    str1='basin\t raw'
    str2='\t \t'
    for model in models:
        m=re.compile('(.*)_(..km)_zsurf').search(model)
        if m is not None:
            str1 += f'\t {m.group(1)}'
            str2 += f'\t {m.group(2)}'
        else:
            str1 += f'\t {model.replace("_zsurf","")}'
            str2 += '\t 15km'              

    print(f'{epoch}\t{h_range[0]} m to {h_range[1]} m, {var}')
    #print(str1)
    #print(str2)
    # remaining lines give basin, range center, and range spread
    for basin in basins:
        raw=pct[epoch][models[1]][h_range]['raw'][basin-1,:]
        thestr=f'{basin}:\t {0.5*(raw[ p1]+raw[p0]):2.3f}({(raw[ p1]-raw[p0]):2.3f})'
        df['raw'][basin-1]=0.5*(raw[ p1]+raw[p0])
        df[sigma_sn['raw']][basin-1]=(raw[ p1]-raw[p0])
        for model in models:        
            corr=pct[epoch][model][h_range]['corr'][basin-1,:]
            thestr += f' \t{0.5*(corr[p1]-corr[p0]):2.3f}({(corr[p1]-corr[p0]):2.3f})'
            df[sn[model]][basin-1]=0.5*(corr[p1]-corr[p0])
            df[sigma_sn[model]][basin-1]=corr[p1]-corr[p0]                  
        #print(thestr)
    #df=pd.DataFrame(df)
    #df=df[columns]
    df=pd.DataFrame(df)[column_list]
    return df

# %%
def highlight_minabs(data, color='yellow'):
    '''
    highlight the maximum in a Series or DataFrame
    '''
    attr = 'background-color: {}'.format(color)
    if data.ndim == 1:  # Series from .apply(axis=0) or axis=1
        is_min = np.abs(data) == np.abs(data).min()
        return [attr if v else '' for v in is_min]
    else:  # from .apply(axis=None)
        is_min = data == np.abs(data).min().min()
        return pd.DataFrame(np.where(is_max, attr, ''),
                            index=data.index, columns=data.columns)

# %%
def bold_abs_lt_first(data):
    '''
    highlight the maximum in a Series or DataFrame
    '''
    attr_good = 'font-weight: bold' 
    attr_bad = 'color : red'
    is_lt = np.abs(data) < np.abs(data[0])
    temp = [attr_good if v else attr_bad for v in is_lt]
    temp[0] = ''
    return temp

# %% [markdown]
# ## Center statistics: Central peak
# Look at the width of the central peak for two epochs.

# %% [markdown]
# #### All data

# %%
df=all_basin_stats(pct, 'all', h_ranges[2],'ctr')
df.style.set_precision(2).apply(highlight_minabs, axis=1, subset=[sn[model] for model in sn.keys()])\
    .apply(highlight_minabs, color='orange', axis=1, subset=[sigma_sn[model] for model in sn.keys()])\
    .apply(bold_abs_lt_first, axis=1, subset=[sn[model] for model in sn.keys()])\
    .apply(bold_abs_lt_first, axis=1, subset=[sigma_sn[model] for model in sn.keys()])
# Out:
# all	-10 m to 5000 m, ctr
# <style  type="text/css" >
#     #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row0_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row0_col2 {
#             background-color:  orange;
#             : ;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row0_col3 {
#             : ;
#             color :  red;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row0_col4 {
#             : ;
#             color :  red;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row0_col5 {
#             : ;
#             color :  red;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row0_col6 {
#             : ;
#             color :  red;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row0_col7 {
#             : ;
#             color :  red;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row0_col8 {
#             : ;
#             color :  red;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row1_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row1_col3 {
#             : ;
#             color :  red;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row1_col4 {
#             : ;
#             color :  red;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row1_col5 {
#             : ;
#             color :  red;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row1_col6 {
#             : ;
#             font-weight:  bold;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row1_col7 {
#             : ;
#             color :  red;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row1_col8 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row2_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row2_col2 {
#             background-color:  orange;
#             : ;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row2_col3 {
#             : ;
#             color :  red;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row2_col4 {
#             : ;
#             color :  red;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row2_col5 {
#             : ;
#             color :  red;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row2_col6 {
#             : ;
#             color :  red;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row2_col7 {
#             : ;
#             color :  red;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row2_col8 {
#             : ;
#             color :  red;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row3_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row3_col3 {
#             : ;
#             color :  red;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row3_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row3_col5 {
#             : ;
#             color :  red;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row3_col6 {
#             : ;
#             color :  red;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row3_col7 {
#             : ;
#             color :  red;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row3_col8 {
#             : ;
#             color :  red;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row4_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row4_col3 {
#             : ;
#             color :  red;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row4_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row4_col5 {
#             : ;
#             color :  red;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row4_col6 {
#             : ;
#             color :  red;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row4_col7 {
#             : ;
#             color :  red;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row4_col8 {
#             : ;
#             color :  red;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row5_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row5_col3 {
#             : ;
#             color :  red;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row5_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row5_col5 {
#             : ;
#             color :  red;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row5_col6 {
#             : ;
#             color :  red;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row5_col7 {
#             : ;
#             color :  red;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row5_col8 {
#             : ;
#             color :  red;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row6_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row6_col2 {
#             background-color:  orange;
#             : ;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row6_col3 {
#             : ;
#             color :  red;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row6_col4 {
#             : ;
#             color :  red;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row6_col5 {
#             : ;
#             color :  red;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row6_col6 {
#             : ;
#             color :  red;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row6_col7 {
#             : ;
#             color :  red;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row6_col8 {
#             : ;
#             color :  red;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row7_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row7_col3 {
#             : ;
#             color :  red;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row7_col4 {
#             : ;
#             color :  red;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row7_col5 {
#             : ;
#             color :  red;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row7_col6 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row7_col7 {
#             : ;
#             color :  red;
#         }    #T_c977d496_fe04_11ea_ac00_ac1f6b600c08row7_col8 {
#             : ;
#             color :  red;
#         }</style><table id="T_c977d496_fe04_11ea_ac00_ac1f6b600c08" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >basin</th>        <th class="col_heading level0 col1" >raw</th>        <th class="col_heading level0 col2" >$\sigma_{raw}$</th>        <th class="col_heading level0 col3" >GSFC_v1.1</th>        <th class="col_heading level0 col4" >$\sigma_{GSFC_v1.1}$</th>        <th class="col_heading level0 col5" >M3.11.2ERA6</th>        <th class="col_heading level0 col6" >$\sigma_{M3.11.2ERA6}$</th>        <th class="col_heading level0 col7" >M311.2NC20</th>        <th class="col_heading level0 col8" >$\sigma_{M311.2NC20}$</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c977d496_fe04_11ea_ac00_ac1f6b600c08level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_c977d496_fe04_11ea_ac00_ac1f6b600c08row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_c977d496_fe04_11ea_ac00_ac1f6b600c08row0_col1" class="data row0 col1" >-0.02</td>
#                         <td id="T_c977d496_fe04_11ea_ac00_ac1f6b600c08row0_col2" class="data row0 col2" >0.18</td>
#                         <td id="T_c977d496_fe04_11ea_ac00_ac1f6b600c08row0_col3" class="data row0 col3" >0.11</td>
#                         <td id="T_c977d496_fe04_11ea_ac00_ac1f6b600c08row0_col4" class="data row0 col4" >0.22</td>

# %% [markdown]
# #### All data, low elevation:

# %%
df=all_basin_stats(pct, 'all', h_ranges[0],'ctr')
df.style.set_precision(2).apply(highlight_minabs, axis=1, subset=[sn[model] for model in sn.keys()])\
    .apply(highlight_minabs, color='orange', axis=1, subset=[sigma_sn[model] for model in sn.keys()])\
    .apply(bold_abs_lt_first, axis=1, subset=[sn[model] for model in sn.keys()])\
    .apply(bold_abs_lt_first, axis=1, subset=[sigma_sn[model] for model in sn.keys()])
# Out:
# all	-10 m to 2000 m, ctr
# <style  type="text/css" >
#     #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row0_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row0_col2 {
#             background-color:  orange;
#             : ;
#         }    #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row0_col3 {
#             : ;
#             color :  red;
#         }    #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row0_col4 {
#             : ;
#             color :  red;
#         }    #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row0_col5 {
#             : ;
#             color :  red;
#         }    #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row0_col6 {
#             : ;
#             color :  red;
#         }    #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row0_col7 {
#             : ;
#             color :  red;
#         }    #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row0_col8 {
#             : ;
#             color :  red;
#         }    #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row1_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row1_col3 {
#             : ;
#             color :  red;
#         }    #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row1_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row1_col5 {
#             : ;
#             color :  red;
#         }    #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row1_col6 {
#             : ;
#             color :  red;
#         }    #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row1_col7 {
#             : ;
#             color :  red;
#         }    #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row1_col8 {
#             : ;
#             color :  red;
#         }    #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row2_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row2_col3 {
#             : ;
#             color :  red;
#         }    #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row2_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row2_col5 {
#             : ;
#             color :  red;
#         }    #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row2_col6 {
#             : ;
#             font-weight:  bold;
#         }    #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row2_col7 {
#             : ;
#             color :  red;
#         }    #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row2_col8 {
#             : ;
#             font-weight:  bold;
#         }    #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row3_col3 {
#             background-color:  yellow;
#             font-weight:  bold;
#         }    #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row3_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row3_col5 {
#             : ;
#             color :  red;
#         }    #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row3_col6 {
#             : ;
#             color :  red;
#         }    #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row3_col7 {
#             : ;
#             color :  red;
#         }    #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row3_col8 {
#             : ;
#             color :  red;
#         }    #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row4_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row4_col3 {
#             : ;
#             color :  red;
#         }    #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row4_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row4_col5 {
#             : ;
#             color :  red;
#         }    #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row4_col6 {
#             : ;
#             font-weight:  bold;
#         }    #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row4_col7 {
#             : ;
#             color :  red;
#         }    #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row4_col8 {
#             : ;
#             font-weight:  bold;
#         }    #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row5_col3 {
#             background-color:  yellow;
#             font-weight:  bold;
#         }    #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row5_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row5_col5 {
#             : ;
#             color :  red;
#         }    #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row5_col6 {
#             : ;
#             font-weight:  bold;
#         }    #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row5_col7 {
#             : ;
#             color :  red;
#         }    #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row5_col8 {
#             : ;
#             font-weight:  bold;
#         }    #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row6_col3 {
#             background-color:  yellow;
#             font-weight:  bold;
#         }    #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row6_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row6_col5 {
#             : ;
#             color :  red;
#         }    #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row6_col6 {
#             : ;
#             color :  red;
#         }    #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row6_col7 {
#             : ;
#             color :  red;
#         }    #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row6_col8 {
#             : ;
#             color :  red;
#         }    #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row7_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row7_col3 {
#             : ;
#             color :  red;
#         }    #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row7_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row7_col5 {
#             : ;
#             color :  red;
#         }    #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row7_col6 {
#             : ;
#             font-weight:  bold;
#         }    #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row7_col7 {
#             : ;
#             color :  red;
#         }    #T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row7_col8 {
#             : ;
#             font-weight:  bold;
#         }</style><table id="T_cb02d310_fe04_11ea_ac00_ac1f6b600c08" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >basin</th>        <th class="col_heading level0 col1" >raw</th>        <th class="col_heading level0 col2" >$\sigma_{raw}$</th>        <th class="col_heading level0 col3" >GSFC_v1.1</th>        <th class="col_heading level0 col4" >$\sigma_{GSFC_v1.1}$</th>        <th class="col_heading level0 col5" >M3.11.2ERA6</th>        <th class="col_heading level0 col6" >$\sigma_{M3.11.2ERA6}$</th>        <th class="col_heading level0 col7" >M311.2NC20</th>        <th class="col_heading level0 col8" >$\sigma_{M311.2NC20}$</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cb02d310_fe04_11ea_ac00_ac1f6b600c08level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row0_col1" class="data row0 col1" >-0.02</td>
#                         <td id="T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row0_col2" class="data row0 col2" >0.23</td>
#                         <td id="T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row0_col3" class="data row0 col3" >0.13</td>
#                         <td id="T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row0_col4" class="data row0 col4" >0.26</td>
#                         <td id="T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row0_col5" class="data row0 col5" >0.15</td>
#                         <td id="T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row0_col6" class="data row0 col6" >0.29</td>
#                         <td id="T_cb02d310_fe04_11ea_ac00_ac1f6b600c08row0_col7" class="data row0 col7" >0.18</td>
#                         <td id="T_cb02d310_fe04_11ea_ac00_ac1f6b600c

# %% [markdown]
# #### All data, high elevation:

# %%
df=all_basin_stats(pct, 'all', h_ranges[1],'ctr')
df.style.set_precision(2).apply(highlight_minabs, axis=1, subset=[sn[model] for model in sn.keys()])\
    .apply(highlight_minabs, color='orange', axis=1, subset=[sigma_sn[model] for model in sn.keys()])\
    .apply(bold_abs_lt_first, axis=1, subset=[sn[model] for model in sn.keys()])\
    .apply(bold_abs_lt_first, axis=1, subset=[sigma_sn[model] for model in sn.keys()])
# Out:
# all	2000 m to 5000 m, ctr
# <style  type="text/css" >
#     #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row0_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row0_col3 {
#             : ;
#             color :  red;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row0_col4 {
#             : ;
#             color :  red;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row0_col5 {
#             : ;
#             color :  red;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row0_col6 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row0_col7 {
#             : ;
#             color :  red;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row0_col8 {
#             : ;
#             color :  red;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row1_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row1_col3 {
#             : ;
#             color :  red;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row1_col4 {
#             : ;
#             color :  red;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row1_col5 {
#             : ;
#             color :  red;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row1_col6 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row1_col7 {
#             : ;
#             color :  red;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row1_col8 {
#             : ;
#             font-weight:  bold;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row2_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row2_col2 {
#             background-color:  orange;
#             : ;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row2_col3 {
#             : ;
#             color :  red;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row2_col4 {
#             : ;
#             color :  red;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row2_col5 {
#             : ;
#             color :  red;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row2_col6 {
#             : ;
#             color :  red;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row2_col7 {
#             : ;
#             color :  red;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row2_col8 {
#             : ;
#             color :  red;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row3_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row3_col2 {
#             background-color:  orange;
#             : ;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row3_col3 {
#             : ;
#             color :  red;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row3_col4 {
#             : ;
#             color :  red;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row3_col5 {
#             : ;
#             color :  red;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row3_col6 {
#             : ;
#             color :  red;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row3_col7 {
#             : ;
#             color :  red;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row3_col8 {
#             : ;
#             color :  red;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row4_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row4_col2 {
#             background-color:  orange;
#             : ;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row4_col3 {
#             : ;
#             color :  red;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row4_col4 {
#             : ;
#             color :  red;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row4_col5 {
#             : ;
#             color :  red;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row4_col6 {
#             : ;
#             color :  red;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row4_col7 {
#             : ;
#             color :  red;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row4_col8 {
#             : ;
#             color :  red;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row5_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row5_col2 {
#             background-color:  orange;
#             : ;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row5_col3 {
#             : ;
#             color :  red;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row5_col4 {
#             : ;
#             color :  red;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row5_col5 {
#             : ;
#             color :  red;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row5_col6 {
#             : ;
#             color :  red;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row5_col7 {
#             : ;
#             color :  red;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row5_col8 {
#             : ;
#             color :  red;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row6_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row6_col2 {
#             background-color:  orange;
#             : ;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row6_col3 {
#             : ;
#             color :  red;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row6_col4 {
#             : ;
#             color :  red;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row6_col5 {
#             : ;
#             color :  red;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row6_col6 {
#             : ;
#             color :  red;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row6_col7 {
#             : ;
#             color :  red;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row6_col8 {
#             : ;
#             color :  red;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row7_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row7_col3 {
#             : ;
#             color :  red;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row7_col4 {
#             : ;
#             color :  red;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row7_col5 {
#             : ;
#             color :  red;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row7_col6 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row7_col7 {
#             : ;
#             color :  red;
#         }    #T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row7_col8 {
#             : ;
#             color :  red;
#         }</style><table id="T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >basin</th>        <th class="col_heading level0 col1" >raw</th>        <th class="col_heading level0 col2" >$\sigma_{raw}$</th>        <th class="col_heading level0 col3" >GSFC_v1.1</th>        <th class="col_heading level0 col4" >$\sigma_{GSFC_v1.1}$</th>        <th class="col_heading level0 col5" >M3.11.2ERA6</th>        <th class="col_heading level0 col6" >$\sigma_{M3.11.2ERA6}$</th>        <th class="col_heading level0 col7" >M311.2NC20</th>        <th class="col_heading level0 col8" >$\sigma_{M311.2NC20}$</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row0_col1" class="data row0 col1" >-0.02</td>
#                         <td id="T_cc2c9d8e_fe04_11ea_ac00_ac1f6b600c08row0_col2" class="data row0 col2" >0.13</td>
#                         <td id="T_cc2c9d8e_fe04_11ea_ac

# %% [markdown]
# ### All non-melt data:

# %%
df=all_basin_stats(pct, 'non_melt', h_ranges[2],'ctr')
df.style.set_precision(2).apply(highlight_minabs, axis=1, subset=[sn[model] for model in sn.keys()])\
    .apply(highlight_minabs, color='orange', axis=1, subset=[sigma_sn[model] for model in sn.keys()])\
    .apply(bold_abs_lt_first, axis=1, subset=[sn[model] for model in sn.keys()])\
    .apply(bold_abs_lt_first, axis=1, subset=[sigma_sn[model] for model in sn.keys()])
# Out:
# non_melt	-10 m to 5000 m, ctr
# <style  type="text/css" >
#     #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row0_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row0_col2 {
#             background-color:  orange;
#             : ;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row0_col3 {
#             : ;
#             color :  red;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row0_col4 {
#             : ;
#             color :  red;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row0_col5 {
#             : ;
#             color :  red;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row0_col6 {
#             : ;
#             color :  red;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row0_col7 {
#             : ;
#             color :  red;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row0_col8 {
#             : ;
#             color :  red;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row1_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row1_col2 {
#             background-color:  orange;
#             : ;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row1_col3 {
#             : ;
#             color :  red;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row1_col4 {
#             : ;
#             color :  red;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row1_col5 {
#             : ;
#             color :  red;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row1_col6 {
#             : ;
#             color :  red;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row1_col7 {
#             : ;
#             color :  red;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row1_col8 {
#             : ;
#             color :  red;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row2_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row2_col2 {
#             background-color:  orange;
#             : ;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row2_col3 {
#             : ;
#             color :  red;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row2_col4 {
#             : ;
#             color :  red;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row2_col5 {
#             : ;
#             color :  red;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row2_col6 {
#             : ;
#             color :  red;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row2_col7 {
#             : ;
#             color :  red;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row2_col8 {
#             : ;
#             color :  red;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row3_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row3_col3 {
#             : ;
#             color :  red;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row3_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row3_col5 {
#             : ;
#             color :  red;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row3_col6 {
#             : ;
#             color :  red;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row3_col7 {
#             : ;
#             color :  red;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row3_col8 {
#             : ;
#             color :  red;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row4_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row4_col3 {
#             : ;
#             color :  red;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row4_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row4_col5 {
#             : ;
#             color :  red;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row4_col6 {
#             : ;
#             color :  red;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row4_col7 {
#             : ;
#             color :  red;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row4_col8 {
#             : ;
#             color :  red;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row5_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row5_col2 {
#             background-color:  orange;
#             : ;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row5_col3 {
#             : ;
#             color :  red;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row5_col4 {
#             : ;
#             color :  red;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row5_col5 {
#             : ;
#             color :  red;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row5_col6 {
#             : ;
#             color :  red;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row5_col7 {
#             : ;
#             color :  red;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row5_col8 {
#             : ;
#             color :  red;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row6_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row6_col2 {
#             background-color:  orange;
#             : ;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row6_col3 {
#             : ;
#             color :  red;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row6_col4 {
#             : ;
#             color :  red;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row6_col5 {
#             : ;
#             color :  red;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row6_col6 {
#             : ;
#             color :  red;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row6_col7 {
#             : ;
#             color :  red;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row6_col8 {
#             : ;
#             color :  red;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row7_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row7_col3 {
#             : ;
#             color :  red;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row7_col4 {
#             : ;
#             color :  red;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row7_col5 {
#             : ;
#             color :  red;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row7_col6 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row7_col7 {
#             : ;
#             color :  red;
#         }    #T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row7_col8 {
#             : ;
#             color :  red;
#         }</style><table id="T_cd480a64_fe04_11ea_ac00_ac1f6b600c08" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >basin</th>        <th class="col_heading level0 col1" >raw</th>        <th class="col_heading level0 col2" >$\sigma_{raw}$</th>        <th class="col_heading level0 col3" >GSFC_v1.1</th>        <th class="col_heading level0 col4" >$\sigma_{GSFC_v1.1}$</th>        <th class="col_heading level0 col5" >M3.11.2ERA6</th>        <th class="col_heading level0 col6" >$\sigma_{M3.11.2ERA6}$</th>        <th class="col_heading level0 col7" >M311.2NC20</th>        <th class="col_heading level0 col8" >$\sigma_{M311.2NC20}$</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cd480a64_fe04_11ea_ac00_ac1f6b600c08level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row0_col1" class="data row0 col1" >-0.00</td>
#                         <td id="T_cd480a64_fe04_11ea_ac00_ac1f6b600c08row0_col2" class="data row0 col2" >0.18</td>
#                         <td id="T_cd480a64_fe04_11ea_ac00_ac1

# %% [markdown]
# ### All melt data:

# %%
df=all_basin_stats(pct, 'melt', h_ranges[2],'ctr')
df.style.set_precision(2).apply(highlight_minabs, axis=1, subset=[sn[model] for model in sn.keys()])\
    .apply(highlight_minabs, color='orange', axis=1, subset=[sigma_sn[model] for model in sn.keys()])\
    .apply(bold_abs_lt_first, axis=1, subset=[sn[model] for model in sn.keys()])\
    .apply(bold_abs_lt_first, axis=1, subset=[sigma_sn[model] for model in sn.keys()])
# Out:
# melt	-10 m to 5000 m, ctr
# <style  type="text/css" >
#     #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row0_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row0_col2 {
#             background-color:  orange;
#             : ;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row0_col3 {
#             : ;
#             color :  red;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row0_col4 {
#             : ;
#             color :  red;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row0_col5 {
#             : ;
#             color :  red;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row0_col6 {
#             : ;
#             color :  red;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row0_col7 {
#             : ;
#             color :  red;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row0_col8 {
#             : ;
#             color :  red;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row1_col3 {
#             : ;
#             font-weight:  bold;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row1_col4 {
#             : ;
#             color :  red;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row1_col5 {
#             : ;
#             color :  red;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row1_col6 {
#             : ;
#             color :  red;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row1_col7 {
#             background-color:  yellow;
#             font-weight:  bold;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row1_col8 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row2_col3 {
#             background-color:  yellow;
#             font-weight:  bold;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row2_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row2_col5 {
#             : ;
#             font-weight:  bold;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row2_col6 {
#             : ;
#             color :  red;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row2_col7 {
#             : ;
#             font-weight:  bold;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row2_col8 {
#             : ;
#             font-weight:  bold;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row3_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row3_col3 {
#             : ;
#             color :  red;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row3_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row3_col5 {
#             : ;
#             color :  red;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row3_col6 {
#             : ;
#             color :  red;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row3_col7 {
#             : ;
#             color :  red;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row3_col8 {
#             : ;
#             color :  red;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row4_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row4_col2 {
#             background-color:  orange;
#             : ;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row4_col3 {
#             : ;
#             color :  red;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row4_col4 {
#             : ;
#             color :  red;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row4_col5 {
#             : ;
#             color :  red;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row4_col6 {
#             : ;
#             color :  red;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row4_col7 {
#             : ;
#             color :  red;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row4_col8 {
#             : ;
#             color :  red;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row5_col3 {
#             background-color:  yellow;
#             font-weight:  bold;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row5_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row5_col5 {
#             : ;
#             font-weight:  bold;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row5_col6 {
#             : ;
#             font-weight:  bold;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row5_col7 {
#             : ;
#             font-weight:  bold;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row5_col8 {
#             : ;
#             color :  red;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row6_col3 {
#             background-color:  yellow;
#             font-weight:  bold;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row6_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row6_col5 {
#             : ;
#             font-weight:  bold;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row6_col6 {
#             : ;
#             color :  red;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row6_col7 {
#             : ;
#             color :  red;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row6_col8 {
#             : ;
#             color :  red;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row7_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row7_col2 {
#             background-color:  orange;
#             : ;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row7_col3 {
#             : ;
#             color :  red;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row7_col4 {
#             : ;
#             color :  red;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row7_col5 {
#             : ;
#             color :  red;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row7_col6 {
#             : ;
#             color :  red;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row7_col7 {
#             : ;
#             color :  red;
#         }    #T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row7_col8 {
#             : ;
#             color :  red;
#         }</style><table id="T_ce387bac_fe04_11ea_ac00_ac1f6b600c08" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >basin</th>        <th class="col_heading level0 col1" >raw</th>        <th class="col_heading level0 col2" >$\sigma_{raw}$</th>        <th class="col_heading level0 col3" >GSFC_v1.1</th>        <th class="col_heading level0 col4" >$\sigma_{GSFC_v1.1}$</th>        <th class="col_heading level0 col5" >M3.11.2ERA6</th>        <th class="col_heading level0 col6" >$\sigma_{M3.11.2ERA6}$</th>        <th class="col_heading level0 col7" >M311.2NC20</th>        <th class="col_heading level0 col8" >$\sigma_{M311.2NC20}$</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ce387bac_fe04_11ea_ac00_ac1f6b600c08level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row0_col1" class="data row0 col1" >-0.08</td>
#                         <td id="T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row0_col2" class="data row0 col2" >0.18</td>
#                         <td id="T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row0_col3" class="data row0 col3" >0.11</td>
#                         <td id="T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row0_col4" class="data row0 col4" >0.22</td>
#                         <td id="T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row0_col5" class="data row0 col5" >0.12</td>
#                         <td id="T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row0_col6" class="data row0 col6" >0.24</td>
#                         <td id="T_ce387bac_fe04_11ea_ac00_ac1f6b600c08row0_col7" class="data

# %% [markdown]
# ### All melt data, at low elevation:

# %%
df=all_basin_stats(pct, 'melt', h_ranges[0],'ctr')
df.style.set_precision(2).apply(highlight_minabs, axis=1, subset=[sn[model] for model in sn.keys()])\
    .apply(highlight_minabs, color='orange', axis=1, subset=[sigma_sn[model] for model in sn.keys()])\
    .apply(bold_abs_lt_first, axis=1, subset=[sn[model] for model in sn.keys()])\
    .apply(bold_abs_lt_first, axis=1, subset=[sigma_sn[model] for model in sn.keys()])
# Out:
# melt	-10 m to 2000 m, ctr
# <style  type="text/css" >
#     #T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row0_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row0_col2 {
#             background-color:  orange;
#             : ;
#         }    #T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row0_col3 {
#             : ;
#             color :  red;
#         }    #T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row0_col4 {
#             : ;
#             color :  red;
#         }    #T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row0_col5 {
#             : ;
#             color :  red;
#         }    #T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row0_col6 {
#             : ;
#             color :  red;
#         }    #T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row0_col7 {
#             : ;
#             color :  red;
#         }    #T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row0_col8 {
#             : ;
#             color :  red;
#         }    #T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row1_col3 {
#             background-color:  yellow;
#             font-weight:  bold;
#         }    #T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row1_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row1_col5 {
#             : ;
#             font-weight:  bold;
#         }    #T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row1_col6 {
#             : ;
#             font-weight:  bold;
#         }    #T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row1_col7 {
#             : ;
#             font-weight:  bold;
#         }    #T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row1_col8 {
#             : ;
#             font-weight:  bold;
#         }    #T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row2_col3 {
#             background-color:  yellow;
#             font-weight:  bold;
#         }    #T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row2_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row2_col5 {
#             : ;
#             font-weight:  bold;
#         }    #T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row2_col6 {
#             : ;
#             font-weight:  bold;
#         }    #T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row2_col7 {
#             : ;
#             font-weight:  bold;
#         }    #T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row2_col8 {
#             : ;
#             font-weight:  bold;
#         }    #T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row3_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row3_col3 {
#             : ;
#             color :  red;
#         }    #T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row3_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row3_col5 {
#             : ;
#             color :  red;
#         }    #T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row3_col6 {
#             : ;
#             color :  red;
#         }    #T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row3_col7 {
#             : ;
#             color :  red;
#         }    #T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row3_col8 {
#             : ;
#             color :  red;
#         }    #T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row4_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row4_col3 {
#             : ;
#             color :  red;
#         }    #T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row4_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row4_col5 {
#             : ;
#             color :  red;
#         }    #T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row4_col6 {
#             : ;
#             color :  red;
#         }    #T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row4_col7 {
#             : ;
#             color :  red;
#         }    #T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row4_col8 {
#             : ;
#             color :  red;
#         }    #T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row5_col3 {
#             background-color:  yellow;
#             font-weight:  bold;
#         }    #T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row5_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row5_col5 {
#             : ;
#             font-weight:  bold;
#         }    #T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row5_col6 {
#             : ;
#             font-weight:  bold;
#         }    #T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row5_col7 {
#             : ;
#             font-weight:  bold;
#         }    #T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row5_col8 {
#             : ;
#             font-weight:  bold;
#         }    #T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row6_col3 {
#             background-color:  yellow;
#             font-weight:  bold;
#         }    #T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row6_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row6_col5 {
#             : ;
#             font-weight:  bold;
#         }    #T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row6_col6 {
#             : ;
#             font-weight:  bold;
#         }    #T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row6_col7 {
#             : ;
#             font-weight:  bold;
#         }    #T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row6_col8 {
#             : ;
#             font-weight:  bold;
#         }    #T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row7_col3 {
#             background-color:  yellow;
#             font-weight:  bold;
#         }    #T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row7_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row7_col5 {
#             : ;
#             font-weight:  bold;
#         }    #T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row7_col6 {
#             : ;
#             font-weight:  bold;
#         }    #T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row7_col7 {
#             : ;
#             font-weight:  bold;
#         }    #T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row7_col8 {
#             : ;
#             font-weight:  bold;
#         }</style><table id="T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >basin</th>        <th class="col_heading level0 col1" >raw</th>        <th class="col_heading level0 col2" >$\sigma_{raw}$</th>        <th class="col_heading level0 col3" >GSFC_v1.1</th>        <th class="col_heading level0 col4" >$\sigma_{GSFC_v1.1}$</th>        <th class="col_heading level0 col5" >M3.11.2ERA6</th>        <th class="col_heading level0 col6" >$\sigma_{M3.11.2ERA6}$</th>        <th class="col_heading level0 col7" >M311.2NC20</th>        <th class="col_heading level0 col8" >$\sigma_{M311.2NC20}$</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row0_col1" class="data row0 col1" >-0.09</td>
#                         <td id="T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row0_col2" class="data row0 col2" >0.22</td>
#                         <td id="T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row0_col3" class="data row0 col3" >0.13</td>
#                         <td id="T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row0_col4" class="data row0 col4" >0.26</td>
#                         <td id="T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row0_col5" class="data row0 col5" >0.15</td>
#                         <td id="T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row0_col6" class="data row0 col6" >0.30</td>
#                         <td id="T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row0_col7" class="data row0 col7" >0.16</td>
#                         <td id="T_cf5b03e2_fe04_11ea_ac00_ac1f6b600c08row0_col8" class="data row0 col8" >0.32</td>
#             </tr>
#             <tr>
#                         <t

# %% [markdown]
# ### All non-melt data, at low elevation:

# %%
df=all_basin_stats(pct, 'non_melt', h_ranges[0],'ctr')
df.style.set_precision(2).apply(highlight_minabs, axis=1, subset=[sn[model] for model in sn.keys()])\
    .apply(highlight_minabs, color='orange', axis=1, subset=[sigma_sn[model] for model in sn.keys()])\
    .apply(bold_abs_lt_first, axis=1, subset=[sn[model] for model in sn.keys()])\
    .apply(bold_abs_lt_first, axis=1, subset=[sigma_sn[model] for model in sn.keys()])
# Out:
# non_melt	-10 m to 2000 m, ctr
# <style  type="text/css" >
#     #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row0_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row0_col2 {
#             background-color:  orange;
#             : ;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row0_col3 {
#             : ;
#             color :  red;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row0_col4 {
#             : ;
#             color :  red;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row0_col5 {
#             : ;
#             color :  red;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row0_col6 {
#             : ;
#             color :  red;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row0_col7 {
#             : ;
#             color :  red;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row0_col8 {
#             : ;
#             color :  red;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row1_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row1_col3 {
#             : ;
#             color :  red;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row1_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row1_col5 {
#             : ;
#             color :  red;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row1_col6 {
#             : ;
#             color :  red;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row1_col7 {
#             : ;
#             color :  red;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row1_col8 {
#             : ;
#             color :  red;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row2_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row2_col3 {
#             : ;
#             color :  red;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row2_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row2_col5 {
#             : ;
#             color :  red;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row2_col6 {
#             : ;
#             font-weight:  bold;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row2_col7 {
#             : ;
#             color :  red;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row2_col8 {
#             : ;
#             font-weight:  bold;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row3_col3 {
#             background-color:  yellow;
#             font-weight:  bold;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row3_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row3_col5 {
#             : ;
#             color :  red;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row3_col6 {
#             : ;
#             color :  red;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row3_col7 {
#             : ;
#             color :  red;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row3_col8 {
#             : ;
#             color :  red;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row4_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row4_col3 {
#             : ;
#             color :  red;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row4_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row4_col5 {
#             : ;
#             color :  red;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row4_col6 {
#             : ;
#             font-weight:  bold;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row4_col7 {
#             : ;
#             color :  red;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row4_col8 {
#             : ;
#             font-weight:  bold;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row5_col3 {
#             background-color:  yellow;
#             font-weight:  bold;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row5_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row5_col5 {
#             : ;
#             color :  red;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row5_col6 {
#             : ;
#             font-weight:  bold;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row5_col7 {
#             : ;
#             color :  red;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row5_col8 {
#             : ;
#             font-weight:  bold;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row6_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row6_col3 {
#             : ;
#             color :  red;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row6_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row6_col5 {
#             : ;
#             color :  red;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row6_col6 {
#             : ;
#             color :  red;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row6_col7 {
#             : ;
#             color :  red;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row6_col8 {
#             : ;
#             font-weight:  bold;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row7_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row7_col3 {
#             : ;
#             color :  red;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row7_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row7_col5 {
#             : ;
#             color :  red;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row7_col6 {
#             : ;
#             font-weight:  bold;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row7_col7 {
#             : ;
#             color :  red;
#         }    #T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row7_col8 {
#             : ;
#             font-weight:  bold;
#         }</style><table id="T_d1028c24_fe04_11ea_ac00_ac1f6b600c08" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >basin</th>        <th class="col_heading level0 col1" >raw</th>        <th class="col_heading level0 col2" >$\sigma_{raw}$</th>        <th class="col_heading level0 col3" >GSFC_v1.1</th>        <th class="col_heading level0 col4" >$\sigma_{GSFC_v1.1}$</th>        <th class="col_heading level0 col5" >M3.11.2ERA6</th>        <th class="col_heading level0 col6" >$\sigma_{M3.11.2ERA6}$</th>        <th class="col_heading level0 col7" >M311.2NC20</th>        <th class="col_heading level0 col8" >$\sigma_{M311.2NC20}$</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d1028c24_fe04_11ea_ac00_ac1f6b600c08level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row0_col1" class="data row0 col1" >0.00</td>
#                         <td id="T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row0_col2" class="data row0 col2" >0.22</td>
#                         <td id="T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row0_col3" class="data row0 col3" >0.13</td>
#                         <td id="T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row0_col4" class="data row0 col4" >0.25</td>
#                         <td id="T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row0_col5" class="data row0 col5" >0.15</td>
#                         <td id="T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row0_col6" class="data row0 col6" >0.29</td>
#                         <td id="T_d1028c24_fe04_11ea_ac00_ac1f6b600c08row0_col7" class="

# %% [markdown]
# ### All non-melt data, at high elevation:

# %%
df=all_basin_stats(pct, 'non_melt', h_ranges[1],'ctr')
df.style.set_precision(2).apply(highlight_minabs, axis=1, subset=[sn[model] for model in sn.keys()])\
    .apply(highlight_minabs, color='orange', axis=1, subset=[sigma_sn[model] for model in sn.keys()])\
    .apply(bold_abs_lt_first, axis=1, subset=[sn[model] for model in sn.keys()])\
    .apply(bold_abs_lt_first, axis=1, subset=[sigma_sn[model] for model in sn.keys()])
# Out:
# non_melt	2000 m to 5000 m, ctr
# <style  type="text/css" >
#     #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row0_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row0_col3 {
#             : ;
#             color :  red;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row0_col4 {
#             : ;
#             color :  red;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row0_col5 {
#             : ;
#             color :  red;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row0_col6 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row0_col7 {
#             : ;
#             color :  red;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row0_col8 {
#             : ;
#             color :  red;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row1_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row1_col3 {
#             : ;
#             color :  red;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row1_col4 {
#             : ;
#             color :  red;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row1_col5 {
#             : ;
#             color :  red;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row1_col6 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row1_col7 {
#             : ;
#             color :  red;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row1_col8 {
#             : ;
#             font-weight:  bold;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row2_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row2_col2 {
#             background-color:  orange;
#             : ;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row2_col3 {
#             : ;
#             color :  red;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row2_col4 {
#             : ;
#             color :  red;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row2_col5 {
#             : ;
#             color :  red;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row2_col6 {
#             : ;
#             color :  red;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row2_col7 {
#             : ;
#             color :  red;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row2_col8 {
#             : ;
#             color :  red;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row3_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row3_col2 {
#             background-color:  orange;
#             : ;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row3_col3 {
#             : ;
#             color :  red;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row3_col4 {
#             : ;
#             color :  red;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row3_col5 {
#             : ;
#             color :  red;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row3_col6 {
#             : ;
#             color :  red;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row3_col7 {
#             : ;
#             color :  red;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row3_col8 {
#             : ;
#             color :  red;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row4_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row4_col2 {
#             background-color:  orange;
#             : ;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row4_col3 {
#             : ;
#             color :  red;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row4_col4 {
#             : ;
#             color :  red;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row4_col5 {
#             : ;
#             color :  red;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row4_col6 {
#             : ;
#             color :  red;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row4_col7 {
#             : ;
#             color :  red;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row4_col8 {
#             : ;
#             color :  red;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row5_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row5_col2 {
#             background-color:  orange;
#             : ;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row5_col3 {
#             : ;
#             color :  red;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row5_col4 {
#             : ;
#             color :  red;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row5_col5 {
#             : ;
#             color :  red;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row5_col6 {
#             : ;
#             color :  red;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row5_col7 {
#             : ;
#             color :  red;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row5_col8 {
#             : ;
#             color :  red;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row6_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row6_col2 {
#             background-color:  orange;
#             : ;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row6_col3 {
#             : ;
#             color :  red;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row6_col4 {
#             : ;
#             color :  red;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row6_col5 {
#             : ;
#             color :  red;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row6_col6 {
#             : ;
#             color :  red;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row6_col7 {
#             : ;
#             color :  red;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row6_col8 {
#             : ;
#             color :  red;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row7_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row7_col3 {
#             : ;
#             color :  red;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row7_col4 {
#             : ;
#             color :  red;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row7_col5 {
#             : ;
#             color :  red;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row7_col6 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row7_col7 {
#             : ;
#             color :  red;
#         }    #T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row7_col8 {
#             : ;
#             color :  red;
#         }</style><table id="T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >basin</th>        <th class="col_heading level0 col1" >raw</th>        <th class="col_heading level0 col2" >$\sigma_{raw}$</th>        <th class="col_heading level0 col3" >GSFC_v1.1</th>        <th class="col_heading level0 col4" >$\sigma_{GSFC_v1.1}$</th>        <th class="col_heading level0 col5" >M3.11.2ERA6</th>        <th class="col_heading level0 col6" >$\sigma_{M3.11.2ERA6}$</th>        <th class="col_heading level0 col7" >M311.2NC20</th>        <th class="col_heading level0 col8" >$\sigma_{M311.2NC20}$</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row0_col1" class="data row0 col1" >-0.01</td>
#                         <td id="T_d2612b7a_fe04_11ea_ac00_ac1f6b600c08row0_col2" class="data row0 col2" >0.13</td>
#                         <td id="T_d2612b7a_fe04_11ea_ac

# %% [markdown]
# ### All melt data, at high elevation:

# %%
df=all_basin_stats(pct, 'melt', h_ranges[1],'ctr')
df.style.set_precision(2).apply(highlight_minabs, axis=1, subset=[sn[model] for model in sn.keys()])\
    .apply(highlight_minabs, color='orange', axis=1, subset=[sigma_sn[model] for model in sn.keys()])\
    .apply(bold_abs_lt_first, axis=1, subset=[sn[model] for model in sn.keys()])\
    .apply(bold_abs_lt_first, axis=1, subset=[sigma_sn[model] for model in sn.keys()])
# Out:
# melt	2000 m to 5000 m, ctr
# <style  type="text/css" >
#     #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row0_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row0_col2 {
#             background-color:  orange;
#             : ;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row0_col3 {
#             : ;
#             color :  red;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row0_col4 {
#             : ;
#             color :  red;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row0_col5 {
#             : ;
#             color :  red;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row0_col6 {
#             : ;
#             color :  red;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row0_col7 {
#             : ;
#             color :  red;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row0_col8 {
#             : ;
#             color :  red;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row1_col2 {
#             background-color:  orange;
#             : ;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row1_col3 {
#             : ;
#             color :  red;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row1_col4 {
#             : ;
#             color :  red;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row1_col5 {
#             : ;
#             font-weight:  bold;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row1_col6 {
#             : ;
#             color :  red;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row1_col7 {
#             background-color:  yellow;
#             font-weight:  bold;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row1_col8 {
#             : ;
#             color :  red;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row2_col2 {
#             background-color:  orange;
#             : ;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row2_col3 {
#             background-color:  yellow;
#             font-weight:  bold;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row2_col4 {
#             : ;
#             color :  red;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row2_col5 {
#             : ;
#             font-weight:  bold;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row2_col6 {
#             : ;
#             color :  red;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row2_col7 {
#             : ;
#             color :  red;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row2_col8 {
#             : ;
#             color :  red;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row3_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row3_col3 {
#             : ;
#             color :  red;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row3_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row3_col5 {
#             : ;
#             color :  red;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row3_col6 {
#             : ;
#             color :  red;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row3_col7 {
#             : ;
#             color :  red;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row3_col8 {
#             : ;
#             color :  red;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row4_col2 {
#             background-color:  orange;
#             : ;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row4_col3 {
#             background-color:  yellow;
#             font-weight:  bold;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row4_col4 {
#             : ;
#             color :  red;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row4_col5 {
#             : ;
#             color :  red;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row4_col6 {
#             : ;
#             color :  red;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row4_col7 {
#             : ;
#             color :  red;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row4_col8 {
#             : ;
#             color :  red;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row5_col2 {
#             background-color:  orange;
#             : ;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row5_col3 {
#             background-color:  yellow;
#             font-weight:  bold;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row5_col4 {
#             : ;
#             color :  red;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row5_col5 {
#             : ;
#             color :  red;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row5_col6 {
#             : ;
#             color :  red;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row5_col7 {
#             : ;
#             color :  red;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row5_col8 {
#             : ;
#             color :  red;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row6_col2 {
#             background-color:  orange;
#             : ;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row6_col3 {
#             background-color:  yellow;
#             font-weight:  bold;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row6_col4 {
#             : ;
#             color :  red;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row6_col5 {
#             : ;
#             font-weight:  bold;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row6_col6 {
#             : ;
#             color :  red;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row6_col7 {
#             : ;
#             color :  red;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row6_col8 {
#             : ;
#             color :  red;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row7_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row7_col2 {
#             background-color:  orange;
#             : ;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row7_col3 {
#             : ;
#             color :  red;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row7_col4 {
#             : ;
#             color :  red;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row7_col5 {
#             : ;
#             color :  red;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row7_col6 {
#             : ;
#             color :  red;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row7_col7 {
#             : ;
#             color :  red;
#         }    #T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row7_col8 {
#             : ;
#             color :  red;
#         }</style><table id="T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >basin</th>        <th class="col_heading level0 col1" >raw</th>        <th class="col_heading level0 col2" >$\sigma_{raw}$</th>        <th class="col_heading level0 col3" >GSFC_v1.1</th>        <th class="col_heading level0 col4" >$\sigma_{GSFC_v1.1}$</th>        <th class="col_heading level0 col5" >M3.11.2ERA6</th>        <th class="col_heading level0 col6" >$\sigma_{M3.11.2ERA6}$</th>        <th class="col_heading level0 col7" >M311.2NC20</th>        <th class="col_heading level0 col8" >$\sigma_{M311.2NC20}$</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row0_col1" class="data row0 col1" >-0.06</td>
#                         <td id="T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row0_col2" class="data row0 col2" >0.12</td>
#                         <td id="T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row0_col3" class="data row0 col3" >0.09</td>
#                         <td id="T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row0_col4" class="data row0 col4" >0.18</td>
#                         <td id="T_d2612b7b_fe04_11ea_ac00_ac1f6b600c08row0_col5" cl

# %% [markdown]
# #### Epoch 1 (Q4 of 2018 to Q2 of 2019), low elevation:

# %%
df=all_basin_stats(pct, epochs[0], h_ranges[0],'ctr')
df.style.set_precision(2).apply(highlight_minabs, axis=1, subset=[sn[model] for model in sn.keys()])\
    .apply(highlight_minabs, color='orange', axis=1, subset=[sigma_sn[model] for model in sn.keys()])\
    .apply(bold_abs_lt_first, axis=1, subset=[sn[model] for model in sn.keys()])\
    .apply(bold_abs_lt_first, axis=1, subset=[sigma_sn[model] for model in sn.keys()])
# Out:
# 2018.Q4-2019.Q2	-10 m to 2000 m, ctr
# <style  type="text/css" >
#     #T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row0_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row0_col3 {
#             : ;
#             color :  red;
#         }    #T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row0_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row0_col5 {
#             : ;
#             color :  red;
#         }    #T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row0_col6 {
#             : ;
#             color :  red;
#         }    #T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row0_col7 {
#             : ;
#             color :  red;
#         }    #T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row0_col8 {
#             : ;
#             color :  red;
#         }    #T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row1_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row1_col3 {
#             : ;
#             color :  red;
#         }    #T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row1_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row1_col5 {
#             : ;
#             color :  red;
#         }    #T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row1_col6 {
#             : ;
#             color :  red;
#         }    #T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row1_col7 {
#             : ;
#             color :  red;
#         }    #T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row1_col8 {
#             : ;
#             font-weight:  bold;
#         }    #T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row2_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row2_col3 {
#             : ;
#             color :  red;
#         }    #T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row2_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row2_col5 {
#             : ;
#             color :  red;
#         }    #T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row2_col6 {
#             : ;
#             color :  red;
#         }    #T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row2_col7 {
#             : ;
#             color :  red;
#         }    #T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row2_col8 {
#             : ;
#             font-weight:  bold;
#         }    #T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row3_col3 {
#             background-color:  yellow;
#             font-weight:  bold;
#         }    #T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row3_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row3_col5 {
#             : ;
#             font-weight:  bold;
#         }    #T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row3_col6 {
#             : ;
#             font-weight:  bold;
#         }    #T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row3_col7 {
#             : ;
#             font-weight:  bold;
#         }    #T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row3_col8 {
#             : ;
#             font-weight:  bold;
#         }    #T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row4_col3 {
#             : ;
#             font-weight:  bold;
#         }    #T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row4_col4 {
#             : ;
#             font-weight:  bold;
#         }    #T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row4_col5 {
#             background-color:  yellow;
#             font-weight:  bold;
#         }    #T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row4_col6 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row4_col7 {
#             : ;
#             color :  red;
#         }    #T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row4_col8 {
#             : ;
#             font-weight:  bold;
#         }    #T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row5_col3 {
#             : ;
#             font-weight:  bold;
#         }    #T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row5_col4 {
#             : ;
#             font-weight:  bold;
#         }    #T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row5_col5 {
#             : ;
#             font-weight:  bold;
#         }    #T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row5_col6 {
#             : ;
#             font-weight:  bold;
#         }    #T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row5_col7 {
#             background-color:  yellow;
#             font-weight:  bold;
#         }    #T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row5_col8 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row6_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row6_col2 {
#             background-color:  orange;
#             : ;
#         }    #T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row6_col3 {
#             : ;
#             color :  red;
#         }    #T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row6_col4 {
#             : ;
#             color :  red;
#         }    #T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row6_col5 {
#             : ;
#             color :  red;
#         }    #T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row6_col6 {
#             : ;
#             color :  red;
#         }    #T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row6_col7 {
#             : ;
#             color :  red;
#         }    #T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row6_col8 {
#             : ;
#             color :  red;
#         }    #T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row7_col3 {
#             background-color:  yellow;
#             font-weight:  bold;
#         }    #T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row7_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row7_col5 {
#             : ;
#             font-weight:  bold;
#         }    #T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row7_col6 {
#             : ;
#             color :  red;
#         }    #T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row7_col7 {
#             : ;
#             font-weight:  bold;
#         }    #T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row7_col8 {
#             : ;
#             color :  red;
#         }</style><table id="T_d477c18a_fe04_11ea_ac00_ac1f6b600c08" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >basin</th>        <th class="col_heading level0 col1" >raw</th>        <th class="col_heading level0 col2" >$\sigma_{raw}$</th>        <th class="col_heading level0 col3" >GSFC_v1.1</th>        <th class="col_heading level0 col4" >$\sigma_{GSFC_v1.1}$</th>        <th class="col_heading level0 col5" >M3.11.2ERA6</th>        <th class="col_heading level0 col6" >$\sigma_{M3.11.2ERA6}$</th>        <th class="col_heading level0 col7" >M311.2NC20</th>        <th class="col_heading level0 col8" >$\sigma_{M311.2NC20}$</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d477c18a_fe04_11ea_ac00_ac1f6b600c08level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row0_col1" class="data row0 col1" >-0.04</td>
#                         <td id="T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row0_col2" class="data row0 col2" >0.19</td>
#                         <td id="T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row0_col3" class="data row0 col3" >0.09</td>
#                         <td id="T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row0_col4" class="data row0 col4" >0.18</td>
#                         <td id="T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row0_col5" class="data row0 col5" >0.11</td>
#                         <td id="T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row0_col6" class="data row0 col6" >0.21</td>
#                         <td id="T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row0_col7" class="data row0 col7" >0.11</td>
#                         <td id="T_d477c18a_fe04_11ea_ac00_ac1f6b600c08row0_col8" class="data row0 col8" >0.23</td>

# %% [markdown]
# #### Epoch 1 (Q4 of 2018 to Q2 of 2019), high elevation:

# %%
df=all_basin_stats(pct, epochs[0], h_ranges[1],'ctr')
df.style.set_precision(2).apply(highlight_minabs, axis=1, subset=[sn[model] for model in sn.keys()])\
    .apply(highlight_minabs, color='orange', axis=1, subset=[sigma_sn[model] for model in sn.keys()])\
    .apply(bold_abs_lt_first, axis=1, subset=[sn[model] for model in sn.keys()])\
    .apply(bold_abs_lt_first, axis=1, subset=[sigma_sn[model] for model in sn.keys()])
# Out:
# 2018.Q4-2019.Q2	2000 m to 5000 m, ctr
# <style  type="text/css" >
#     #T_d6786688_fe04_11ea_ac00_ac1f6b600c08row0_col3 {
#             background-color:  yellow;
#             font-weight:  bold;
#         }    #T_d6786688_fe04_11ea_ac00_ac1f6b600c08row0_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_d6786688_fe04_11ea_ac00_ac1f6b600c08row0_col5 {
#             : ;
#             font-weight:  bold;
#         }    #T_d6786688_fe04_11ea_ac00_ac1f6b600c08row0_col6 {
#             : ;
#             color :  red;
#         }    #T_d6786688_fe04_11ea_ac00_ac1f6b600c08row0_col7 {
#             : ;
#             font-weight:  bold;
#         }    #T_d6786688_fe04_11ea_ac00_ac1f6b600c08row0_col8 {
#             : ;
#             color :  red;
#         }    #T_d6786688_fe04_11ea_ac00_ac1f6b600c08row1_col3 {
#             background-color:  yellow;
#             font-weight:  bold;
#         }    #T_d6786688_fe04_11ea_ac00_ac1f6b600c08row1_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_d6786688_fe04_11ea_ac00_ac1f6b600c08row1_col5 {
#             : ;
#             font-weight:  bold;
#         }    #T_d6786688_fe04_11ea_ac00_ac1f6b600c08row1_col6 {
#             : ;
#             color :  red;
#         }    #T_d6786688_fe04_11ea_ac00_ac1f6b600c08row1_col7 {
#             : ;
#             font-weight:  bold;
#         }    #T_d6786688_fe04_11ea_ac00_ac1f6b600c08row1_col8 {
#             : ;
#             color :  red;
#         }    #T_d6786688_fe04_11ea_ac00_ac1f6b600c08row2_col3 {
#             background-color:  yellow;
#             font-weight:  bold;
#         }    #T_d6786688_fe04_11ea_ac00_ac1f6b600c08row2_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_d6786688_fe04_11ea_ac00_ac1f6b600c08row2_col5 {
#             : ;
#             color :  red;
#         }    #T_d6786688_fe04_11ea_ac00_ac1f6b600c08row2_col6 {
#             : ;
#             color :  red;
#         }    #T_d6786688_fe04_11ea_ac00_ac1f6b600c08row2_col7 {
#             : ;
#             color :  red;
#         }    #T_d6786688_fe04_11ea_ac00_ac1f6b600c08row2_col8 {
#             : ;
#             color :  red;
#         }    #T_d6786688_fe04_11ea_ac00_ac1f6b600c08row3_col3 {
#             background-color:  yellow;
#             font-weight:  bold;
#         }    #T_d6786688_fe04_11ea_ac00_ac1f6b600c08row3_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_d6786688_fe04_11ea_ac00_ac1f6b600c08row3_col5 {
#             : ;
#             color :  red;
#         }    #T_d6786688_fe04_11ea_ac00_ac1f6b600c08row3_col6 {
#             : ;
#             color :  red;
#         }    #T_d6786688_fe04_11ea_ac00_ac1f6b600c08row3_col7 {
#             : ;
#             color :  red;
#         }    #T_d6786688_fe04_11ea_ac00_ac1f6b600c08row3_col8 {
#             : ;
#             font-weight:  bold;
#         }    #T_d6786688_fe04_11ea_ac00_ac1f6b600c08row4_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_d6786688_fe04_11ea_ac00_ac1f6b600c08row4_col3 {
#             : ;
#             color :  red;
#         }    #T_d6786688_fe04_11ea_ac00_ac1f6b600c08row4_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_d6786688_fe04_11ea_ac00_ac1f6b600c08row4_col5 {
#             : ;
#             color :  red;
#         }    #T_d6786688_fe04_11ea_ac00_ac1f6b600c08row4_col6 {
#             : ;
#             color :  red;
#         }    #T_d6786688_fe04_11ea_ac00_ac1f6b600c08row4_col7 {
#             : ;
#             color :  red;
#         }    #T_d6786688_fe04_11ea_ac00_ac1f6b600c08row4_col8 {
#             : ;
#             color :  red;
#         }    #T_d6786688_fe04_11ea_ac00_ac1f6b600c08row5_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_d6786688_fe04_11ea_ac00_ac1f6b600c08row5_col3 {
#             : ;
#             color :  red;
#         }    #T_d6786688_fe04_11ea_ac00_ac1f6b600c08row5_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_d6786688_fe04_11ea_ac00_ac1f6b600c08row5_col5 {
#             : ;
#             color :  red;
#         }    #T_d6786688_fe04_11ea_ac00_ac1f6b600c08row5_col6 {
#             : ;
#             color :  red;
#         }    #T_d6786688_fe04_11ea_ac00_ac1f6b600c08row5_col7 {
#             : ;
#             color :  red;
#         }    #T_d6786688_fe04_11ea_ac00_ac1f6b600c08row5_col8 {
#             : ;
#             font-weight:  bold;
#         }    #T_d6786688_fe04_11ea_ac00_ac1f6b600c08row6_col3 {
#             background-color:  yellow;
#             font-weight:  bold;
#         }    #T_d6786688_fe04_11ea_ac00_ac1f6b600c08row6_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_d6786688_fe04_11ea_ac00_ac1f6b600c08row6_col5 {
#             : ;
#             color :  red;
#         }    #T_d6786688_fe04_11ea_ac00_ac1f6b600c08row6_col6 {
#             : ;
#             color :  red;
#         }    #T_d6786688_fe04_11ea_ac00_ac1f6b600c08row6_col7 {
#             : ;
#             color :  red;
#         }    #T_d6786688_fe04_11ea_ac00_ac1f6b600c08row6_col8 {
#             : ;
#             color :  red;
#         }    #T_d6786688_fe04_11ea_ac00_ac1f6b600c08row7_col3 {
#             background-color:  yellow;
#             font-weight:  bold;
#         }    #T_d6786688_fe04_11ea_ac00_ac1f6b600c08row7_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_d6786688_fe04_11ea_ac00_ac1f6b600c08row7_col5 {
#             : ;
#             font-weight:  bold;
#         }    #T_d6786688_fe04_11ea_ac00_ac1f6b600c08row7_col6 {
#             : ;
#             color :  red;
#         }    #T_d6786688_fe04_11ea_ac00_ac1f6b600c08row7_col7 {
#             : ;
#             font-weight:  bold;
#         }    #T_d6786688_fe04_11ea_ac00_ac1f6b600c08row7_col8 {
#             : ;
#             color :  red;
#         }</style><table id="T_d6786688_fe04_11ea_ac00_ac1f6b600c08" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >basin</th>        <th class="col_heading level0 col1" >raw</th>        <th class="col_heading level0 col2" >$\sigma_{raw}$</th>        <th class="col_heading level0 col3" >GSFC_v1.1</th>        <th class="col_heading level0 col4" >$\sigma_{GSFC_v1.1}$</th>        <th class="col_heading level0 col5" >M3.11.2ERA6</th>        <th class="col_heading level0 col6" >$\sigma_{M3.11.2ERA6}$</th>        <th class="col_heading level0 col7" >M311.2NC20</th>        <th class="col_heading level0 col8" >$\sigma_{M311.2NC20}$</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d6786688_fe04_11ea_ac00_ac1f6b600c08level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d6786688_fe04_11ea_ac00_ac1f6b600c08row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_d6786688_fe04_11ea_ac00_ac1f6b600c08row0_col1" class="data row0 col1" >-0.10</td>
#                         <td id="T_d6786688_fe04_11ea_ac00_ac1f6b600c08row0_col2" class="data row0 col2" >0.09</td>
#                         <td id="T_d6786688_fe04_11ea_ac00_ac1f6b600c08row0_col3" class="data row0 col3" >0.04</td>
#                         <td id="T_d6786688_fe04_11ea_ac00_ac1f6b600c08row0_col4" class="data row0 col4" >0.08</td>
#                         <td id="T_d6786688_fe04_11ea_ac00_ac1f6b600c08row0_col5" class="data row0 col5" >0.05</td>
#                         <td id="T_d6786688_fe04_11ea_ac00_ac1f6b600c08row0_col6" class="data row0 col6" >0.11</td>
#                         <td id="T_d6786688_fe04_11ea_ac00_ac1f6b600c08row0_col7" class="data row0 col7" >0.06</td>
#                         <td id="T_d6786688_fe04_11ea_ac00_ac1f6b600c08row0_col8" class="data row0 col8" >0.12</td>
#             </tr>
#             <tr>
#                         <th id="T_d6786688_fe04_11ea_ac00_ac1f6b600c08level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_d6786688_fe04_11ea_ac00_ac1f6b600c08row1_col0" class="data row1 col0" >2</td>
#                         <td id="T_d6786688_

# %% [markdown]
# #### Epoch 2: (Q1 of 2019 to Q2 of 2019), at low elevation:

# %%
df=all_basin_stats(pct, epochs[1], h_ranges[0],'ctr')
df.style.set_precision(2).apply(highlight_minabs, axis=1, subset=[sn[model] for model in sn.keys()])\
    .apply(highlight_minabs, color='orange', axis=1, subset=[sigma_sn[model] for model in sn.keys()])\
    .apply(bold_abs_lt_first, axis=1, subset=[sn[model] for model in sn.keys()])\
    .apply(bold_abs_lt_first, axis=1, subset=[sigma_sn[model] for model in sn.keys()])
# Out:
# 2019.Q1-2019.Q2	-10 m to 2000 m, ctr
# <style  type="text/css" >
#     #T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row0_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row0_col3 {
#             : ;
#             color :  red;
#         }    #T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row0_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row0_col5 {
#             : ;
#             color :  red;
#         }    #T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row0_col6 {
#             : ;
#             color :  red;
#         }    #T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row0_col7 {
#             : ;
#             color :  red;
#         }    #T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row0_col8 {
#             : ;
#             color :  red;
#         }    #T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row1_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row1_col3 {
#             : ;
#             color :  red;
#         }    #T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row1_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row1_col5 {
#             : ;
#             color :  red;
#         }    #T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row1_col6 {
#             : ;
#             color :  red;
#         }    #T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row1_col7 {
#             : ;
#             color :  red;
#         }    #T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row1_col8 {
#             : ;
#             font-weight:  bold;
#         }    #T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row2_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row2_col3 {
#             : ;
#             color :  red;
#         }    #T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row2_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row2_col5 {
#             : ;
#             color :  red;
#         }    #T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row2_col6 {
#             : ;
#             color :  red;
#         }    #T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row2_col7 {
#             : ;
#             color :  red;
#         }    #T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row2_col8 {
#             : ;
#             color :  red;
#         }    #T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row3_col3 {
#             background-color:  yellow;
#             font-weight:  bold;
#         }    #T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row3_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row3_col5 {
#             : ;
#             font-weight:  bold;
#         }    #T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row3_col6 {
#             : ;
#             font-weight:  bold;
#         }    #T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row3_col7 {
#             : ;
#             font-weight:  bold;
#         }    #T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row3_col8 {
#             : ;
#             color :  red;
#         }    #T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row4_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row4_col3 {
#             : ;
#             color :  red;
#         }    #T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row4_col4 {
#             : ;
#             font-weight:  bold;
#         }    #T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row4_col5 {
#             : ;
#             color :  red;
#         }    #T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row4_col6 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row4_col7 {
#             : ;
#             color :  red;
#         }    #T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row4_col8 {
#             : ;
#             font-weight:  bold;
#         }    #T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row5_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row5_col3 {
#             : ;
#             color :  red;
#         }    #T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row5_col4 {
#             : ;
#             font-weight:  bold;
#         }    #T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row5_col5 {
#             : ;
#             color :  red;
#         }    #T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row5_col6 {
#             : ;
#             font-weight:  bold;
#         }    #T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row5_col7 {
#             : ;
#             color :  red;
#         }    #T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row5_col8 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row6_col3 {
#             : ;
#             font-weight:  bold;
#         }    #T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row6_col4 {
#             : ;
#             font-weight:  bold;
#         }    #T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row6_col5 {
#             background-color:  yellow;
#             font-weight:  bold;
#         }    #T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row6_col6 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row6_col7 {
#             : ;
#             font-weight:  bold;
#         }    #T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row6_col8 {
#             : ;
#             font-weight:  bold;
#         }    #T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row7_col3 {
#             background-color:  yellow;
#             font-weight:  bold;
#         }    #T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row7_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row7_col5 {
#             : ;
#             color :  red;
#         }    #T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row7_col6 {
#             : ;
#             font-weight:  bold;
#         }    #T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row7_col7 {
#             : ;
#             color :  red;
#         }    #T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row7_col8 {
#             : ;
#             font-weight:  bold;
#         }</style><table id="T_d79858b6_fe04_11ea_ac00_ac1f6b600c08" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >basin</th>        <th class="col_heading level0 col1" >raw</th>        <th class="col_heading level0 col2" >$\sigma_{raw}$</th>        <th class="col_heading level0 col3" >GSFC_v1.1</th>        <th class="col_heading level0 col4" >$\sigma_{GSFC_v1.1}$</th>        <th class="col_heading level0 col5" >M3.11.2ERA6</th>        <th class="col_heading level0 col6" >$\sigma_{M3.11.2ERA6}$</th>        <th class="col_heading level0 col7" >M311.2NC20</th>        <th class="col_heading level0 col8" >$\sigma_{M311.2NC20}$</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d79858b6_fe04_11ea_ac00_ac1f6b600c08level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row0_col1" class="data row0 col1" >-0.02</td>
#                         <td id="T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row0_col2" class="data row0 col2" >0.15</td>
#                         <td id="T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row0_col3" class="data row0 col3" >0.07</td>
#                         <td id="T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row0_col4" class="data row0 col4" >0.14</td>
#                         <td id="T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row0_col5" class="data row0 col5" >0.08</td>
#                         <td id="T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row0_col6" class="data row0 col6" >0.16</td>
#                         <td id="T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row0_col7" class="data row0 col7" >0.08</td>
#                         <td id="T_d79858b6_fe04_11ea_ac00_ac1f6b600c08row0_col8" class="data row0 col8" >0.16</td>

# %% [markdown]
# #### Epoch 2: (Q1 of 2019 to Q2 of 2019), at high elevation:

# %%
df=all_basin_stats(pct, epochs[1], h_ranges[1],'ctr')
df.style.set_precision(2).apply(highlight_minabs, axis=1, subset=[sn[model] for model in sn.keys()])\
    .apply(highlight_minabs, color='orange', axis=1, subset=[sigma_sn[model] for model in sn.keys()])\
    .apply(bold_abs_lt_first, axis=1, subset=[sn[model] for model in sn.keys()])\
    .apply(bold_abs_lt_first, axis=1, subset=[sigma_sn[model] for model in sn.keys()])
# Out:
# 2019.Q1-2019.Q2	2000 m to 5000 m, ctr
# <style  type="text/css" >
#     #T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row0_col3 {
#             background-color:  yellow;
#             font-weight:  bold;
#         }    #T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row0_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row0_col5 {
#             : ;
#             font-weight:  bold;
#         }    #T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row0_col6 {
#             : ;
#             font-weight:  bold;
#         }    #T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row0_col7 {
#             : ;
#             font-weight:  bold;
#         }    #T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row0_col8 {
#             : ;
#             color :  red;
#         }    #T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row1_col3 {
#             background-color:  yellow;
#             font-weight:  bold;
#         }    #T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row1_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row1_col5 {
#             : ;
#             font-weight:  bold;
#         }    #T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row1_col6 {
#             : ;
#             color :  red;
#         }    #T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row1_col7 {
#             : ;
#             font-weight:  bold;
#         }    #T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row1_col8 {
#             : ;
#             color :  red;
#         }    #T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row2_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row2_col3 {
#             : ;
#             color :  red;
#         }    #T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row2_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row2_col5 {
#             : ;
#             color :  red;
#         }    #T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row2_col6 {
#             : ;
#             color :  red;
#         }    #T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row2_col7 {
#             : ;
#             color :  red;
#         }    #T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row2_col8 {
#             : ;
#             color :  red;
#         }    #T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row3_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row3_col3 {
#             : ;
#             color :  red;
#         }    #T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row3_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row3_col5 {
#             : ;
#             color :  red;
#         }    #T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row3_col6 {
#             : ;
#             font-weight:  bold;
#         }    #T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row3_col7 {
#             : ;
#             color :  red;
#         }    #T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row3_col8 {
#             : ;
#             font-weight:  bold;
#         }    #T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row4_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row4_col3 {
#             : ;
#             color :  red;
#         }    #T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row4_col4 {
#             : ;
#             font-weight:  bold;
#         }    #T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row4_col5 {
#             : ;
#             color :  red;
#         }    #T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row4_col6 {
#             : ;
#             font-weight:  bold;
#         }    #T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row4_col7 {
#             : ;
#             color :  red;
#         }    #T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row4_col8 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row5_col3 {
#             background-color:  yellow;
#             font-weight:  bold;
#         }    #T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row5_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row5_col5 {
#             : ;
#             font-weight:  bold;
#         }    #T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row5_col6 {
#             : ;
#             font-weight:  bold;
#         }    #T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row5_col7 {
#             : ;
#             font-weight:  bold;
#         }    #T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row5_col8 {
#             : ;
#             font-weight:  bold;
#         }    #T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row6_col3 {
#             background-color:  yellow;
#             font-weight:  bold;
#         }    #T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row6_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row6_col5 {
#             : ;
#             font-weight:  bold;
#         }    #T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row6_col6 {
#             : ;
#             font-weight:  bold;
#         }    #T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row6_col7 {
#             : ;
#             font-weight:  bold;
#         }    #T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row6_col8 {
#             : ;
#             font-weight:  bold;
#         }    #T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row7_col3 {
#             background-color:  yellow;
#             font-weight:  bold;
#         }    #T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row7_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row7_col5 {
#             : ;
#             color :  red;
#         }    #T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row7_col6 {
#             : ;
#             font-weight:  bold;
#         }    #T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row7_col7 {
#             : ;
#             color :  red;
#         }    #T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row7_col8 {
#             : ;
#             font-weight:  bold;
#         }</style><table id="T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >basin</th>        <th class="col_heading level0 col1" >raw</th>        <th class="col_heading level0 col2" >$\sigma_{raw}$</th>        <th class="col_heading level0 col3" >GSFC_v1.1</th>        <th class="col_heading level0 col4" >$\sigma_{GSFC_v1.1}$</th>        <th class="col_heading level0 col5" >M3.11.2ERA6</th>        <th class="col_heading level0 col6" >$\sigma_{M3.11.2ERA6}$</th>        <th class="col_heading level0 col7" >M311.2NC20</th>        <th class="col_heading level0 col8" >$\sigma_{M311.2NC20}$</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row0_col1" class="data row0 col1" >-0.05</td>
#                         <td id="T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row0_col2" class="data row0 col2" >0.09</td>
#                         <td id="T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row0_col3" class="data row0 col3" >0.04</td>
#                         <td id="T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row0_col4" class="data row0 col4" >0.09</td>
#                         <td id="T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row0_col5" class="data row0 col5" >0.05</td>
#                         <td id="T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row0_col6" class="data row0 col6" >0.09</td>
#                         <td id="T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row0_col7" class="data row0 col7" >0.05</td>
#                         <td id="T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08row0_col8" class="data row0 col8" >0.10</td>
#             </tr>
#             <tr>
#                         <th id="T_d89bcf68_fe04_11ea_ac00_ac1f6b600c08level0_row1" class="row_heading level0 row1" >1</th>

# %% [markdown]
# GSFC seems to have done the best job in reducing the model spread.  There isn't a substantial winner here among the MAR models.  The higher resolution models (MAR_v311_ERA @ 15km and Mar_v311.2 @ 10km) have smaller spreads in a few basins, but the differences are small. The corrections also don't seem to capture a large share of the variance in the data (spreads are comparable between raw and corrected data)

# %% [markdown]
# #### Epoch 3: (Q2 of 2019 to Q3 of 2019), at low elevation:

# %%
df=all_basin_stats(pct, epochs[2], h_ranges[1],'ctr')
df.style.set_precision(2).apply(highlight_minabs, axis=1, subset=[sn[model] for model in sn.keys()])\
    .apply(highlight_minabs, color='orange', axis=1, subset=[sigma_sn[model] for model in sn.keys()])\
    .apply(bold_abs_lt_first, axis=1, subset=[sn[model] for model in sn.keys()])\
    .apply(bold_abs_lt_first, axis=1, subset=[sigma_sn[model] for model in sn.keys()])
# Out:
# 2019.Q2-2019.Q3	2000 m to 5000 m, ctr
# <style  type="text/css" >
#     #T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row0_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row0_col3 {
#             : ;
#             color :  red;
#         }    #T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row0_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row0_col5 {
#             : ;
#             color :  red;
#         }    #T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row0_col6 {
#             : ;
#             font-weight:  bold;
#         }    #T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row0_col7 {
#             : ;
#             color :  red;
#         }    #T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row0_col8 {
#             : ;
#             font-weight:  bold;
#         }    #T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row1_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row1_col3 {
#             : ;
#             color :  red;
#         }    #T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row1_col4 {
#             : ;
#             color :  red;
#         }    #T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row1_col5 {
#             : ;
#             color :  red;
#         }    #T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row1_col6 {
#             : ;
#             color :  red;
#         }    #T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row1_col7 {
#             : ;
#             color :  red;
#         }    #T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row1_col8 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row2_col3 {
#             background-color:  yellow;
#             font-weight:  bold;
#         }    #T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row2_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row2_col5 {
#             : ;
#             color :  red;
#         }    #T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row2_col6 {
#             : ;
#             color :  red;
#         }    #T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row2_col7 {
#             : ;
#             color :  red;
#         }    #T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row2_col8 {
#             : ;
#             color :  red;
#         }    #T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row3_col3 {
#             background-color:  yellow;
#             font-weight:  bold;
#         }    #T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row3_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row3_col5 {
#             : ;
#             color :  red;
#         }    #T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row3_col6 {
#             : ;
#             color :  red;
#         }    #T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row3_col7 {
#             : ;
#             color :  red;
#         }    #T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row3_col8 {
#             : ;
#             color :  red;
#         }    #T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row4_col3 {
#             background-color:  yellow;
#             font-weight:  bold;
#         }    #T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row4_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row4_col5 {
#             : ;
#             font-weight:  bold;
#         }    #T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row4_col6 {
#             : ;
#             font-weight:  bold;
#         }    #T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row4_col7 {
#             : ;
#             font-weight:  bold;
#         }    #T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row4_col8 {
#             : ;
#             color :  red;
#         }    #T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row5_col3 {
#             : ;
#             font-weight:  bold;
#         }    #T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row5_col4 {
#             : ;
#             color :  red;
#         }    #T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row5_col5 {
#             background-color:  yellow;
#             font-weight:  bold;
#         }    #T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row5_col6 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row5_col7 {
#             : ;
#             font-weight:  bold;
#         }    #T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row5_col8 {
#             : ;
#             color :  red;
#         }    #T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row6_col3 {
#             background-color:  yellow;
#             font-weight:  bold;
#         }    #T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row6_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row6_col5 {
#             : ;
#             font-weight:  bold;
#         }    #T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row6_col6 {
#             : ;
#             color :  red;
#         }    #T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row6_col7 {
#             : ;
#             font-weight:  bold;
#         }    #T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row6_col8 {
#             : ;
#             color :  red;
#         }    #T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row7_col1 {
#             background-color:  yellow;
#             : ;
#         }    #T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row7_col3 {
#             : ;
#             color :  red;
#         }    #T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row7_col4 {
#             background-color:  orange;
#             font-weight:  bold;
#         }    #T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row7_col5 {
#             : ;
#             color :  red;
#         }    #T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row7_col6 {
#             : ;
#             color :  red;
#         }    #T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row7_col7 {
#             : ;
#             color :  red;
#         }    #T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row7_col8 {
#             : ;
#             color :  red;
#         }</style><table id="T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >basin</th>        <th class="col_heading level0 col1" >raw</th>        <th class="col_heading level0 col2" >$\sigma_{raw}$</th>        <th class="col_heading level0 col3" >GSFC_v1.1</th>        <th class="col_heading level0 col4" >$\sigma_{GSFC_v1.1}$</th>        <th class="col_heading level0 col5" >M3.11.2ERA6</th>        <th class="col_heading level0 col6" >$\sigma_{M3.11.2ERA6}$</th>        <th class="col_heading level0 col7" >M311.2NC20</th>        <th class="col_heading level0 col8" >$\sigma_{M311.2NC20}$</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row0_col1" class="data row0 col1" >0.00</td>
#                         <td id="T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row0_col2" class="data row0 col2" >0.13</td>
#                         <td id="T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row0_col3" class="data row0 col3" >0.05</td>
#                         <td id="T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row0_col4" class="data row0 col4" >0.10</td>
#                         <td id="T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row0_col5" class="data row0 col5" >0.05</td>
#                         <td id="T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row0_col6" class="data row0 col6" >0.10</td>
#                         <td id="T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row0_col7" class="data row0 col7" >0.06</td>
#                         <td id="T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08row0_col8" class="data row0 col8" >0.11</td>
#             </tr>
#             <tr>
#                         <th id="T_da4ce5b8_fe04_11ea_ac00_ac1f6b600c08level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_da4ce5b8_fe04_11ea_ac00_ac

# %% [markdown]
# Here the corrections seem to both make large reductions in the spread of the signal, and seem to correct for the large drawdown signals.  The statistics are similar across the models, although the v3.11.2 models seem to have modestly better spread than the V3.11 model, and the 10km v3.11.2 is better than the coarser resolution version.

# %% [markdown]
# # deeper dive into individual drainage basins: basin 1

# %%
basin=1
h_range=h_ranges[0]
h_bins=np.arange(-2, 2.01, 0.01)
dh_hist={}
dist_data={}
for model in models:
    dh_hist[model]={ver:np.zeros((len(h_bins)-1, len(epochs))) for ver in ['raw','corr']}
    dh_hist[model].update({ver:np.zeros(len(epochs)) for ver in ['raw_med', 'corr_med']})
    dh_hist[model]['raw_data']={}
    dh_hist[model]['corr_data']={}
    for col, epoch in enumerate(epochs):
        Dsub=D[model][epoch]
        els = np.floor(Dsub.basin)==basin
        els &= (Dsub.h0 > h_range[0])
        els &= (Dsub.h0 < h_range[1])
        Dsub=Dsub[els]
        dh_hist[model]['raw_med'][col] = np.median(Dsub.dh)
        dh_hist[model]['corr_med'][col] = np.median(Dsub.dh_corr)
        dh_hist[model]['raw'][:, col] = np.histogram(Dsub.dh, bins=h_bins, density=True)[0]
        dh_hist[model]['corr'][:, col] = np.histogram(Dsub.dh_corr, bins=h_bins, density=True)[0]
        good=np.abs(Dsub.dh_corr)<2.5
        dh_hist[model]['raw_data'][epoch]=Dsub.dh[good]
        dh_hist[model]['corr_data'][epoch]=Dsub.dh_corr[good]

# %% [markdown]
# This is a nicer way to compare two different models.  There's another version of violinplot that comes up on Google that puts one distribution on the left of each bar and one on the right.  Might be worth exploring.

# %%
basin=6
for count, model in enumerate([models[0], models[1]]):

    fig, hax = plt.subplots(1, len(epochs), gridspec_kw = {'wspace':0, 'hspace':0})

    fig.suptitle(model+' '+str(h_range), fontsize=12)

    for col, epoch in enumerate(epochs):

        V = pd.DataFrame({ "raw_data" : dh_hist[model]['raw_data'][epoch],\
                          "corr_data" : dh_hist[model]['corr_data'][epoch]})
        V = V.stack().reset_index()
        V = V.drop(columns=['level_0'])
        V.columns = ['htype','dh']

        sns.violinplot(x=[epoch[:7]+'\n'+epoch[7:]]*len(V), y='dh', data=V,
                  scale='count', bw=0.05,
                  hue='htype', split=True,
                  palette='RdGy',
                  inner='quartile',
                ax=hax[col])

        hax[col].set_ylim([-2, 2])
        hax[col].legend_.remove()
        if col != 0:
            hax[col].set_ylabel('')
            hax[col].set_yticklabels([])


    handles, labels = hax[0].get_legend_handles_labels()
    fig.legend(handles, labels, 
               loc='lower center', bbox_to_anchor=(0.5, 0.1),
               ncol=2, 
               facecolor='white', framealpha=1)

    fig.tight_layout()
    fig.subplots_adjust(top=0.93)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
models

# %%
def three_sigma_edit_fit(G0, d0, n_iterations=5):
    good0=np.all(np.isfinite(G0), axis=1) & np.isfinite(d0)
    good=good0
    m=np.zeros(G0.shape[1])
    r=np.zeros(d0.shape)
    sigma=np.NaN
    good=np.ones_like(d0, dtype=bool)
    good_last=np.zeros_like(good)
    for ii in range(n_iterations+1):
        G=G0[good,:]
        if (G.shape[0]<G.shape[1]) or np.all(good_last==good):
            break
        m=np.linalg.solve(G.T.dot(G), G.T.dot(d0[good]))
        r=d0-G0.dot(m)
        sigma=RDE(r[good])
        good=good0 & (np.abs(r)<3*sigma)
    return m, r, sigma, good

# %%
def basin_regessions(D, model, basins, epochs, h_range, fits=None):
    temp=[]
    for basin in basins:
        for ind, epoch in enumerate(epochs):
            these = np.floor(D[model][epoch].basin)==basin
            these &= (D[model][epoch].h0 > h_range[0]) & (D[model][epoch].h0 < h_range[1])
            temp1=D[model][epoch][these]
            temp1.assign({'epoch':np.zeros_like(temp1.x)+ind})
            temp += [temp1]
    Dsub=pc.data().from_list(temp)
    Dsub.dh_model=Dsub.dh - Dsub.dh_corr
    h_star = (Dsub.h0-2000)/2000
    RDE_params={'f':0.95, 'scale':0.25}
    
    calc=False
    if fits is None:
        calc=True
        fits={}
        
    key='A'
    G = np.c_[np.ones_like(Dsub.dh_model)]
    if calc:
        m, r, sigma, good=three_sigma_edit_fit(G, Dsub.dh, n_iterations=10)
    else:
        m=fits[key]['m']
        r=Dsub.dh-G.dot(m)
        sigma=three_sigma_edit_fit(np.c_[np.ones_like(Dsub.dh)], r, n_iterations=10)[2]
    sigma_all=RDE(r, **RDE_params)
    fits[key]={'m':m, 'r':r, 'sigma_ctr':sigma, 'sigma':sigma_all,\
               'label':'dh - %3.2f, $\sigma$=%3.3f'}

    key='A+dh_m'
    G = np.c_[np.ones_like(Dsub.dh_model)]
    if calc:
        m, r, sigma, good=three_sigma_edit_fit(G, Dsub.dh_corr, n_iterations=10)
    else:
        m=fits[key]['m']
        r=Dsub.dh_corr-G.dot(m)
        sigma=three_sigma_edit_fit(np.c_[np.ones_like(Dsub.dh)], r, n_iterations=10)[2]
    sigma_all=RDE(r, **RDE_params)
    fits[key]={'m':m, 'r':Dsub.dh_corr, 'sigma_ctr':sigma, 'sigma':sigma_all,\
               'label':'dh - ($dh_m$+%3.2f), $\sigma$=%3.3f'}
    
    key='A+B*h_star'
    G = np.c_[np.ones_like(Dsub.dh_model), h_star]
    if calc:
        m, r, sigma, good= three_sigma_edit_fit(G, Dsub.dh, n_iterations=10)
    else:
        m=fits[key]['m']
        r=Dsub.dh-G.dot(m)
        sigma=three_sigma_edit_fit(np.c_[np.ones_like(Dsub.dh)], r, n_iterations=10)[2]
    sigma_all=RDE(r, **RDE_params)
    fits[key]={'m':m, 'r':r, 'sigma_ctr':sigma, 'sigma':sigma_all,\
                'label':'dh - (%3.2f+%3.2f $h^*$), $\sigma$=%3.3f'}
    
    key='A+B*dh_m'
    G=np.c_[np.ones_like(Dsub.dh_model), Dsub.dh_model]
    if calc:
        m, r, sigma, good = three_sigma_edit_fit(G, Dsub.dh, n_iterations=10)
    else:
        m=fits[key]['m']
        r=Dsub.dh-G.dot(m)
        sigma=three_sigma_edit_fit(np.c_[np.ones_like(Dsub.dh)], r, n_iterations=10)[2]
    sigma_all = RDE(r, **RDE_params)
    fits[key] = {'m':m, 'r':r, 'sigma_ctr':sigma, 'sigma':sigma_all,\
                'label':'dh - (%3.2f+%3.2f $dh_m$), $\sigma$=%3.3f'}
 
    key='A+B*h_star*dh_m'
    G=np.c_[np.ones_like(Dsub.dh_model), Dsub.dh_model*h_star]
    if calc:
        m, r, sigma, good = three_sigma_edit_fit(G, Dsub.dh, n_iterations=10)
    else:
        m=fits[key]['m']
        r=Dsub.dh-G.dot(m)
        sigma=three_sigma_edit_fit(np.c_[np.ones_like(Dsub.dh)], r, n_iterations=10)[2]
    sigma_all = RDE(r, **RDE_params)
    fits[key]={'m':m, 'r':r, 'sigma_ctr':sigma, 'sigma':sigma_all,\
                'label':'dh - (%3.2f + %3.2f $h^*$ $dh_m$), $\sigma$=%3.3f'}
    
    key = 'A+ B*dh_m + C*h_star*dh_m'
    G=np.c_[np.ones_like(Dsub.dh_model), Dsub.dh_model, Dsub.dh_model*h_star]
    if calc:
        m, r, sigma, good = three_sigma_edit_fit(G, Dsub.dh, n_iterations=10)
    else:
        m=fits[key]['m']
        r=Dsub.dh-G.dot(m)
        sigma=three_sigma_edit_fit(np.c_[np.ones_like(Dsub.dh)], r, n_iterations=10)[2]
    sigma_all = RDE(r, **RDE_params)
    fits['A+ B*dh_m + C*h_star*dh_m'] = {'m':m, 'r':r, 'sigma_ctr':sigma, 'sigma':sigma_all,\
                'label':'dh - (%3.2f+%3.2f $dh_m$ + %3.2f $h^*$ $dh_m$), $\sigma$=%3.3f'}                

    return fits, Dsub


def fit_hists(Dsub, fits, keys, colors=None, bins=None):
    if bins is None:
        bins=np.arange(-2.005,  2.005, 0.01)
    if colors is None:
        colors=[None*len(keys)]
    
    for ii, key in enumerate(keys):
        print(key)
        legend_tuple=tuple(list(fits[key]['m'])+[fits[key]['sigma']])
        legend_str=fits[key]['label'] % legend_tuple
        if colors[ii] is not None:
            plt.hist(fits[key]['r'], bins, color=colors[ii], label = legend_str)
        else:
            plt.hist(fits[key]['r'], bins, alpha=0.5, label = legend_str)
    plt.legend()

# %%
model='MARv3_11_2_ERA_6km_zsurf'
fits, Dsub=basin_regessions(D, model, np.arange(1, 10), epochs[0:-1], [-20, 5000])

fig=plt.figure()
ax=fig.add_subplot(111)
colors=[None]*len(fits.keys())
colors[0]='k'
fit_hists(Dsub, fits, fits.keys(), colors)
plt.title(model.replace('_zsurf','') + ' all basins, $Q_{i+1}-Q_i$')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# A
# A+dh_m
# A+B*h_star
# A+B*dh_m
# A+B*h_star*dh_m
# A+ B*dh_m + C*h_star*dh_m
# Text(0.5, 1.0, 'MARv3_11_2_ERA_6km all basins, $Q_{i+1}-Q_i$')

# %%
RDE_params={'f':0.95, 'scale':0.25}
key='A+ B*dh_m + C*h_star*dh_m'
{basin:RDE(fits[key]['r'][np.floor(Dsub.basin)==basin], **RDE_params) for basin in range(1, 9)}
# Out:
# {1: 0.14469038453059235,
#  2: 0.13965985558358152,
#  3: 0.20501689295594472,
#  4: 0.19037576361768527,
#  5: 0.23867044494572576,
#  6: 0.30203905952340043,
#  7: 0.120247171855705,
#  8: 0.15981707099773917}

# %%
plt.figure(); 
plt.hist(fits['A']['r'][np.floor(Dsub.basin)==7], np.arange(-2.005, 2.005, 0.01),color='k');
plt.hist(fits[key]['r'][np.floor(Dsub.basin)==7], np.arange(-2.005, 2.005, 0.01), alpha=0.5);

# %%
plt.figure(); 
plt.hist(fits['A+dh_m']['r'][np.floor(Dsub.basin)==7], np.arange(-2.005, 2.005, 0.01),color='k');
plt.hist(fits[key]['r'][np.floor(Dsub.basin)==7], np.arange(-2.005, 2.005, 0.01), alpha=0.5);

# %%
model='GSFC_fdm_v1_1_zsurf'
fits, Dsub=basin_regessions(D, model, np.arange(1, 10), epochs[0:-1], [-20, 5000])

fig=plt.figure()
ax=fig.add_subplot(111)
colors=[None]*len(fits.keys())
colors[0]='k'
fit_hists(Dsub, fits, fits.keys(), colors)
plt.title(model.replace('_zsurf','') + ' all basins, $Q_{i+1}-Q_i$')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# A
# A+dh_m
# A+B*h_star
# A+B*dh_m
# A+B*h_star*dh_m
# A+ B*dh_m + C*h_star*dh_m
# Text(0.5, 1.0, 'GSFC_fdm_v1_1 all basins, $Q_{i+1}-Q_i$')

# %%
F={}
DD={}
model='GSFC_fdm_v1_1_zsurf'
F[model], DD[model]=basin_regessions(D, model, np.arange(1, 10), epochs[0:-1], [-20, 5000])

model='MARv3_11_2_ERA_6km_zsurf'
F[model], DD[model]=basin_regessions(D, model, np.arange(1, 10), epochs, [-20, 5000])

# %%
fig=plt.figure(figsize=[8, 6])
ax=fig.subplots(3, 5, gridspec_kw={'wspace':0.05, 'hspace':0.05})
strings=epochs

for row, model in enumerate(['Data',  'MARv3_11_2_ERA_6km_zsurf', 'GSFC_fdm_v1_1_zsurf']):
    for col, epoch in enumerate(epochs):
        if row==0:
            ax[row, col].set_title(epoch.replace('-','\n to '))
        if col==0:
            ax[row, col].set_ylabel(model.replace('_zsurf','').replace('_6km',''))
        if model == 'Data':
            this_D=DD['MARv3_11_2_ERA_6km_zsurf']
            temp=this_D[this_D.epoch==col]
            dh=F['MARv3_11_2_ERA_6km_zsurf']['A']['r'][this_D.epoch==col]
        else:
            this_D=DD[model]
            temp=this_D[this_D.epoch==col]            
            dh=F[model]['A+ B*dh_m + C*h_star*dh_m']['r'][this_D.epoch==col]    
        ind=np.argsort(np.abs(dh))    
        hi=ax[row, col].scatter(temp.x[ind], temp.y[ind], 2, c=dh[ind],\
                 vmin=-2.5, vmax=2.5, cmap='Spectral');
        ax[row, col].set_xticks([])
        ax[row, col].set_yticks([])
        plt.axis('equal');
plt.colorbar(hi, ax=ax, shrink=0.5, extend='both', label='$\delta h$, m')
# Out:
# <img src="data:image/png;base64,..." width="799.9999826604674">

# %%
data_file=os.path.join(data_root+'/combined_xover_at_differences_wrtc3.h5')


epochs_c3=strings_xover+['2019.Q2-2019.Q3', '2019.Q2-2019.Q4', '2019.Q2-2020.Q1']
D_c3={}
with h5py.File(data_file,'r') as h5f:
    models=list(h5f.keys())
    print(models)
for model in models:
    D_c3[model]={}
    for epoch in epochs_c3:
        this_group='/'.join(['',model, epoch])
        D_c3[model][epoch]=pc.data().from_h5(data_file, group=this_group)
        D_c3[model][epoch].assign({'basin':np.floor(dbi.__call__((D_c3[model][epoch].y, D_c3[model][epoch].x))*10)/10})
# Out:
# ['GSFC_fdm_v1_1_zsurf', 'MARv3_11_2_ERA_10km_zsurf', 'MARv3_11_2_ERA_6km_zsurf', 'MARv3_11_2_NCEP_20km_zsurf']

# %%
model='MARv3_11_2_ERA_6km_zsurf'
fits_c3, Dsub_c3 = basin_regessions(D_c3, model, np.arange(1,9), epochs_c3[0:-1], [-20, 5000])

fig=plt.figure()
ax=fig.add_subplot(111)
colors=[None]*len(fits.keys())
colors[0]='k'
fit_hists(Dsub_c3, fits_c3, fits_c3.keys(), colors)
plt.title(model.replace('_zsurf','') + ' all basins, vs 2020 Q2')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# A
# A+dh_m
# A+B*h_star
# A+B*dh_m
# A+B*h_star*dh_m
# A+ B*dh_m + C*h_star*dh_m
# Text(0.5, 1.0, 'MARv3_11_2_ERA_6km all basins, vs 2020 Q2')

# %%
F_c3={}
DD_c3={}
model='GSFC_fdm_v1_1_zsurf'
F_c3[model], DD_c3[model]=basin_regessions(D_c3, model, np.arange(1, 10), epochs_c3[0:-1], [-20, 5000])

model='MARv3_11_2_ERA_6km_zsurf'
F_c3[model], DD_c3[model]=basin_regessions(D_c3, model, np.arange(1, 10), epochs_c3, [-20, 5000])

# %%
fig=plt.figure(figsize=[8, 6])
ax=fig.subplots(3, 5, gridspec_kw={'wspace':0.05, 'hspace':0.05})
strings=epochs

for row, model in enumerate(['Data',  'MARv3_11_2_ERA_6km_zsurf', 'GSFC_fdm_v1_1_zsurf']):
    for col, epoch in enumerate(epochs_c3):
        if row==0:
            ax[row, col].set_title(epoch.replace('-','\n to '))
        if col==0:
            ax[row, col].set_ylabel(model.replace('_zsurf','').replace('_6km',''))
        if model == 'Data':
            this_D=DD_c3['MARv3_11_2_ERA_6km_zsurf']
            temp=this_D[this_D.epoch==col]
            dh=F_c3['MARv3_11_2_ERA_6km_zsurf']['A']['r'][this_D.epoch==col]
        else:
            this_D=DD_c3[model]
            temp=this_D[this_D.epoch==col]            
            dh=F_c3[model]['A+ B*dh_m + C*h_star*dh_m']['r'][this_D.epoch==col]    
        if len(dh) > 0:
            ind=np.argsort(np.abs(dh))    
            hi=ax[row, col].scatter(temp.x[ind], temp.y[ind], 2, c=dh[ind],\
                 vmin=-2.5, vmax=2.5, cmap='Spectral');
        ax[row, col].set_xticks([])
        ax[row, col].set_yticks([])
        plt.axis('equal');
plt.colorbar(hi, ax=ax, shrink=0.5, extend='both', label='$\delta h$, m')
# Out:
# <img src="data:image/png;base64,..." width="799.9999826604674">

# %%
dh.shape
